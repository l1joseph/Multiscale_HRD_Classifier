# %%
# !pwd
# Out:
# /Users/johnsmith/Desktop/Senior_Design_Stuff/Multiscale_HRD_Classifier

# %%
from scipy.stats import pearsonr, mannwhitneyu
from sklearn.metrics import roc_auc_score, roc_curve

# …after you’ve built hrd_df…
import pandas as pd
import numpy as np
from scipy.stats import pearsonr, mannwhitneyu
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Reload and process the data
expr = pd.read_csv(
    'data/validation/GSE173839_ISPY2_AgilentGeneExp_durvaPlusCtr_FFPE_meanCol_geneLevel_n105.txt',
    sep='\t', index_col=0
)
resp = pd.read_csv('data/validation/GSE173839_ISPY2_DurvalumabOlaparibArm_biomarkers.csv')
resp = resp[resp['Arm'] == 'durvalumab/olaparib'].copy()
resp.loc[resp['pCR.status'] == -1, 'pCR.status'] = 0
resp['ResearchID'] = resp['ResearchID'].astype(str)

centroids = pd.read_csv('data/validation/pre_data/Table S4-Table 1.csv', index_col=0, skiprows=1)
# adjust these names if necessary after inspection
sig = centroids[['HRD', 'HR_proficient']]
#print(sig)
genes = sig.index.intersection(expr.index)
samples = expr.columns.intersection(resp['ResearchID'])
expr_sub = expr.loc[genes, samples]
sig_sub  = sig.loc[genes, :]

#print(expr_sub)

# Compute HRD scores
hrd_scores = {}
for samp in samples:
    
    x = expr_sub[samp].values
    #print(np.isnan(x).any())
    print(x)
    x_filt = x[~np.isnan(x)]
    # if np.isnan(x).any():
    #     sig_sub['HRD'].loc[]
    r_hrd = pearsonr(x_filt, sig_sub['HRD'].values)[0]
    r_hrp = pearsonr(x_filt, sig_sub['HR_proficient'].values)[0]
    hrd_scores[samp] = r_hrd - r_hrp

hrd_df = pd.DataFrame.from_dict(hrd_scores, orient='index', columns=['HRD_score']).reset_index().rename(columns={'index':'ResearchID'})
hrd_df = hrd_df.merge(resp[['ResearchID','pCR.status','PARPi7_sig.']], on='ResearchID')
hrd_df['Response'] = hrd_df['pCR.status'].map({0:'Non‑responder', 1:'Responder'})

# ——————————————————————————————————————
# Filter out any rows with missing HRD_score or pCR.status
hrd_clean = hrd_df.dropna(subset=['HRD_score','pCR.status','PARPi7_sig.'])

# 9. Recompute trend‐line stats on the clean subset
x = hrd_clean['PARPi7_sig.']
y = hrd_clean['HRD_score']
r, p_val = pearsonr(x, y)
m, b = np.polyfit(x, y, 1)
plt.figure()
plt.scatter(x, y, alpha=0.7)
xx = np.linspace(x.min(), x.max(), 100)
plt.plot(xx, m*xx + b, color='gray')
plt.annotate(
    f'r = {r:.2f}\np = {p_val:.2e}',
    xy=(0.05, 0.95), xycoords='axes fraction',
    va='top', ha='left',
    bbox=dict(boxstyle="round,pad=0.3", fc="white")
)
plt.xlabel('PARPi7 signature score')
plt.ylabel('HRD score')
plt.title('HRD vs PARPi7 (clean data)')
plt.show()

# 10. ROC curve + AUC
y_true  = hrd_clean['pCR.status']
scores  = hrd_clean['HRD_score']
auc      = roc_auc_score(y_true, scores)
fpr, tpr, _ = roc_curve(y_true, scores)

plt.figure()
plt.plot(fpr, tpr, label=f'AUC = {auc:.2f}')
plt.plot([0,1],[0,1],'--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for HRD score')
plt.legend()
plt.show()

# 11. Mann–Whitney U and Cohen’s d
g0 = hrd_clean.loc[hrd_clean['pCR.status']==0, 'HRD_score']
g1 = hrd_clean.loc[hrd_clean['pCR.status']==1, 'HRD_score']
u_stat, p_mw = mannwhitneyu(g0, g1, alternative='two-sided')
pooled_sd = np.sqrt((g0.std()**2 + g1.std()**2)/2)
cohens_d  = (g1.mean() - g0.mean()) / pooled_sd

print(f"Mann–Whitney U p‐value = {p_mw:.2e}")
print(f"Cohen’s d = {cohens_d:.2f}")
# Out:
# [10.15   9.395  7.456  7.586  5.906  8.67  13.95   9.413  7.117  9.699
#   7.758  7.056  9.258 10.43   8.106 10.81   7.662  7.939  9.696  6.914
#   9.766  8.425  8.29   6.872  6.381 10.1    6.012  7.656  7.076  8.026
#   9.198  7.267  6.862  6.224  9.715 11.47   8.222  6.135 10.38   9.058
#   8.002  6.28   5.568  5.356  7.317  9.97   6.098  8.712  5.686  6.582
#   9.68   9.062  6.71   8.227  8.028  7.183  9.525  9.672  8.88  11.76
#   8.266  9.843  9.305  6.695 10.92  12.2    7.773  7.616  8.58   8.947
#  10.55   9.728  5.681  7.79   9.406  7.482 10.3    8.618  4.506  6.963
#  11.39  11.96   7.103  6.934  7.702 11.19   9.765 10.14   6.436  9.176
#   9.101  8.047  9.855  9.059  6.968 10.03   9.082 10.19  11.01   8.499
#   5.967 12.1    5.661 12.36   7.68  10.57   7.799  7.539  4.898  5.776
#   6.733  4.295 10.6    6.497  7.58   6.803 11.25   8.558  4.09   8.374
#  11.04   6.648  7.668 10.42   8.123  7.978  7.656 10.26   6.33  10.14
#   5.984  9.431  7.72   5.572  9.056  5.452  7.448  8.315 11.83  11.97
#   8.453 11.     9.508  8.626  9.299  7.491  7.258 10.7   11.47   7.437
#   8.934 12.68  11.98   6.846 11.26   8.052  8.442  9.243 10.28   9.892
#   9.25  10.49   8.829  6.811  7.682  7.13  10.19   7.782  8.668  6.236
#  10.57  10.5    9.222  4.708  8.235 10.48   7.852  7.277  8.434  6.82
#   9.06   8.548  7.443  8.603  9.661 11.28  10.08  12.91  12.33   8.732
#   8.732  7.136 12.05  10.1    8.695  6.798  9.715  7.511  8.779  6.415
#   8.206 12.2   10.07   6.899  7.016  7.212  9.505 11.4   10.72   8.124
#   9.967  5.494  7.211  9.623  7.268  7.236  6.28   7.916  7.65   7.467
#   8.788  8.82   7.063]
# [10.79   9.693  8.651  8.782  6.438  8.749 13.8    9.577  7.297  9.095
#  10.81   7.847  9.776 10.34   8.573  9.399  8.545  9.483  7.822  6.426
#   9.992  9.271  9.339  7.528  7.265 10.51   7.208  6.212  7.573  8.348
#   9.611  8.096  7.078  7.159  9.914 11.56   8.417  7.118 10.93   9.048
#   7.398  7.322  5.806  6.448  6.612 10.14   6.591  8.637  5.969  5.451
#   9.754  8.912  6.833  8.74   7.647  5.699  8.506  7.967  8.1   11.28
#   7.03   9.721  8.889  7.36  11.87  10.54   7.136  7.381  8.677  9.25
#   8.968  9.22   5.217  7.724  9.295  8.18  10.49   7.521  5.502  6.67
#   9.621  9.801  8.62   7.159  7.965 11.28   9.583  9.414  7.593 11.03
#   9.358  9.132 10.26   8.869  9.074 11.63   9.566 11.52  11.09   8.563
#   5.285  9.511  6.44  11.29   7.644  9.809  7.348  8.463  6.178  6.608
#   6.796  7.117 10.63   5.842  8.044  7.032 10.82   8.945  5.214  8.974
#  11.5    7.671  8.342 10.39   8.544  7.52   7.889  9.816  6.279 10.09
#   7.243 11.34   6.829  6.27   8.86   5.763  7.126  8.728  8.986 10.27
#   8.591 10.8   10.34   8.891  9.415  7.525  7.587 10.18  10.23   7.335
#   8.753 10.09  11.84   7.335  7.334  7.939  9.077  9.469 12.09   9.557
#   8.53   9.321  8.27   7.303  7.708  8.062 10.09   8.592  8.99   7.325
#  10.86  10.8    9.538  6.395  8.29  10.04   7.83   9.258  8.525  8.783
#  10.03   9.815  8.79   8.973  8.927 11.38   9.362 12.7   10.38   9.788
#   9.093  8.006 11.31   9.706  9.216  8.401  8.38   8.375  7.586  7.764
#   9.373 11.94  10.77   7.615  6.747  8.107 10.13  10.79  10.6    8.394
#  10.07   5.608  6.253 10.18   7.906  7.244  6.776  8.407  7.897  8.654
#   8.913  7.181  7.647]
# [ 9.676  9.433  7.315  7.538  6.383  8.634 13.16   8.356  6.395  9.06
#  11.65   7.361  9.222 10.47   8.162  9.991  8.643  6.826 10.33   7.477
#   9.528  8.586  8.482  8.953  7.123 10.74   6.862  6.066  6.255  7.777
#   8.768  7.693  6.706  7.707  9.526 11.53   8.645  6.722 10.83   9.642
#   8.915  7.732  5.958  6.556  6.497  9.491  7.026 10.43   5.864  5.006
#   9.598  8.67   6.301  6.338  7.672  5.401  9.1    8.828  7.336 11.73
#   8.121 10.16   8.886  7.262 11.95  10.46   7.732  6.029  8.996 10.37
#   9.959 10.8    6.049  9.394 10.21   9.908 11.43   8.648  6.891  6.859
#  10.01  13.34   7.056  6.728  7.989 10.65   9.348  9.641  8.589  9.97
#   8.72   8.592  9.951  8.49   8.157 10.28   9.408  9.445 10.42   7.871
#   4.966 11.01   6.157 10.98   6.668  9.751  7.2    6.465  5.801  5.869
#   5.925  8.605 12.43   6.279  6.992  6.582 10.54   8.506  4.559  8.806
#  10.92   7.144  7.144 10.17   8.241  7.08   7.5    9.565  5.892  9.027
#   6.43   9.55   6.846  6.116  8.22   5.974  7.361  8.11   9.46   9.998
#   8.755 11.44   8.685  8.573 10.29   7.801  7.631 10.59  11.11   8.048
#   9.432 11.15  11.9    6.069  6.054  7.078  8.244  9.217 13.09   9.332
#   8.825  9.648  8.535  8.104  8.27   7.895 10.19   8.296  8.95   7.09
#  10.55  11.31   9.224  6.299  8.875 10.47   7.685 10.33   9.045  9.364
#   9.983 11.91   8.666  8.822 10.24  12.15   9.715 13.22  10.42  10.38
#   8.856  8.814 11.98  10.94  10.24   9.227 10.28   7.07   7.428  6.074
#   7.944 11.22   9.951  6.815  6.658  6.767 10.9    9.922 11.67   7.972
#   9.702  4.856  6.514 10.02   7.097  6.552  6.44   4.968  7.629  7.375
#   8.266  6.333  7.278]
# [11.94  10.54   9.093 11.14   6.908  9.452 13.12   8.834  7.154  8.525
#   9.048  7.286  9.154  6.749  7.076  9.993  8.146  7.901  8.962  8.143
#  10.65   5.634  8.3    6.623  8.207  9.73   6.462  6.359  4.674  7.819
#   9.082  8.102  7.037  6.007  9.744 12.14   8.899  6.917 10.97   9.527
#   8.188  5.884  5.718  5.084  6.074 10.38   7.054  8.777  5.512  5.007
#   9.047  8.806  6.544  9.887  7.864  6.274 11.52   7.257  7.908 11.07
#   7.153  9.192  8.5    7.802  7.374 10.07   8.336  5.044  8.672  7.989
#   8.665 10.08   4.745  6.568 10.88   5.668 10.86   7.729  5.193  6.531
#   9.013 10.66   8.648  7.264  8.641 10.98  10.49   7.926  6.676 10.06
#   9.216  8.774  9.305  9.173  7.242  9.251  9.806 10.63  11.29   7.356
#   4.645 12.11   5.813 10.04   7.214 10.47   7.979  8.156  5.545  6.466
#   6.295  4.424 10.2    6.469  9.303  6.826 10.75   8.995  4.851  8.606
#  11.08   7.406  6.599 11.17   8.172  7.298  7.308  9.3    6.397  9.917
#   6.077  9.14   7.347  4.532  9.14   5.606  7.389  9.069  9.17  10.6
#   7.773 10.52   9.541  9.362  9.456  7.961  7.632 10.8   11.21   7.972
#   8.99  11.4   12.51   6.144  7.862  7.998  9.635  9.544 10.03  10.22
#   8.736 10.23   9.558  7.065  7.614  6.338 10.51   8.259  8.928  7.019
#  11.74  11.1    9.956  5.318  8.114 10.46   7.989  7.351  8.029  7.663
#   8.721  8.705  8.3    7.77   9.528 10.71   9.448 11.94  10.61   8.509
#   9.66   7.114 10.98   9.212  7.936  7.066  8.611  8.492  7.722  6.354
#   8.332 11.85  10.03   6.87   6.838  7.456 11.81  12.93  11.65   8.19
#  10.75   4.65   8.586  9.931  7.924  6.495  6.974  9.964  7.107  7.38
#   8.502  6.243  7.081]
# [11.49  10.81   8.815  7.195  5.739  8.501 14.17   9.291  7.204  9.07
#   6.71   8.389  9.486  7.422  7.598 10.54   8.728  7.206  9.062  5.875
#  10.32   9.522  8.561  7.62   6.56  10.52   6.146  9.543  5.313  8.536
#   9.189  7.799  6.775  6.175  9.81  10.96   7.965  6.282 11.8    9.336
#   6.912  5.526  5.362  4.936  7.349  9.898  6.475  8.039  5.641  6.25
#   9.918  8.427  6.294  7.54   8.014  7.86   9.867  9.195  8.122 11.4
#   7.27   9.885  9.225  6.87  11.18  11.65   7.079  6.556  8.869  7.973
#   9.944 10.18   5.163  7.419  9.564  6.842  9.684  6.379  4.593  6.406
#  10.37  10.1    6.943  7.966  8.406 12.45  10.5    9.317  7.68  10.76
#   9.154  9.22  10.44   9.524  7.154 10.86   9.541 10.12  11.5    7.867
#   4.692 11.6    9.128 11.98   7.226  9.779  7.272  7.208  6.439  6.224
#   7.154  4.244  9.852  5.264  7.726  6.63  11.     8.721  4.1    9.39
#  11.41   7.106  6.851 10.46   8.594  8.219  7.46   9.607  5.854  9.977
#   5.838 10.26   7.459  5.746  9.011  5.073  5.83  10.32   9.953 11.4
#   8.1    9.937  9.986  9.211  9.273  7.365  7.192 10.21  10.68   6.69
#   8.282 11.96  12.16   6.214  9.867  8.32   9.179  9.383  9.702 10.05
#   9.021 10.08   9.088  6.964  7.059  7.206  9.597  8.019  9.376  6.811
#  11.45  10.69   9.644  5.508  8.533 10.58   7.745  8.613  7.706  8.877
#   8.768  8.515  8.821  7.987  9.414 10.16   9.084 12.99  11.14   9.044
#   9.087  7.961 11.76   9.567  9.059  7.416  9.269  7.548  8.685  6.313
#   8.525 12.44  10.91   6.553  7.055  6.844  9.881 10.83  10.04   8.669
#  10.17   5.214  6.838  9.471  6.68   7.033  6.879  8.126  8.045  8.123
#   9.612  6.3    6.924]
# [11.28  10.48   8.194  7.522  7.098  9.556 12.63  10.41   7.65  10.38
#   7.44   7.439  9.817  8.497  7.733  9.792  8.105  7.875  7.744  6.037
#  11.14   7.398  7.755  7.25   7.519  9.873  5.62   8.34   5.706  9.512
#   9.472  8.435  6.899  7.543 10.96  10.33   8.502  6.961  9.557  8.621
#   6.76   6.292  5.866  5.32   6.281  9.371  6.504  7.799  6.471  5.4
#   9.722  9.019  6.978  7.624  7.974  5.712  8.877  7.622  9.017 11.78
#   7.38   9.846  9.662  7.396  9.217 11.58   8.476  6.308  8.438  8.274
#   9.357  9.044  5.431  7.21   9.699  6.616  8.986  6.976  5.307  6.276
#   9.02   9.801  8.899  7.734  7.783 11.31   8.644  8.487  7.805  8.558
#  10.03   9.37   9.833  8.89   7.525 11.02  10.86  10.45  12.23   8.894
#   5.565 10.26   6.372 10.85   8.388 10.02   7.368  7.387  5.18   6.64
#   8.242  4.794  9.509  6.095  8.257  8.213 10.71   9.332  4.929  9.146
#  11.44   6.861  7.584 10.49   7.89   6.984  8.554  9.497  6.489  9.755
#   7.383  9.351  7.752  5.741  8.763  5.741  6.961  9.728 10.08  10.74
#   9.232  9.959  9.823  9.312  8.823  8.166  8.123  9.916  9.79   6.685
#   8.056 11.53  12.43   6.992  8.349  8.788  9.585 10.23  11.54   9.461
#   9.064  9.451  9.93   7.188  7.819  7.888 11.13   9.1    9.902  6.9
#  10.79   9.841 10.25   5.037  7.716  9.488  8.654  7.852  6.897  7.365
#   8.977  6.927  8.582  8.384  9.163 10.75   9.169 11.77  10.63   8.441
#   9.768  7.139 10.17   8.913  8.034  7.609  8.295  8.288  7.954  7.844
#   9.184 11.59  11.1    7.93   7.648  7.222 10.26  10.58  10.86   9.222
#  10.31   5.565  6.957  9.556  7.336  7.234  7.214  9.08   8.584  8.032
#   9.609  7.66   7.374]
# [10.92   9.939  8.241  8.358  7.427  9.464 13.01   9.713  6.941 10.89
#   9.07   7.832  9.548  8.982  8.056  9.77   8.363  8.73   7.721  6.526
#   9.465  9.285  8.285  6.771  8.315  9.585  6.538  7.071  7.175  9.694
#   9.674  8.544  7.239  8.877 11.1   10.52   7.916  8.139 10.95   8.563
#   7.489  7.71   5.753  5.986  6.406  9.197  6.652  7.748  7.212  5.853
#   9.982  9.244  7.779  7.353  7.426  5.751  8.134  7.573  8.469 11.02
#   7.151  8.587  9.916  7.013 10.78   9.677  8.917  7.108  8.826  9.396
#   9.283  9.702  7.21   7.309  9.666  7.494 10.79   8.055  5.674  6.916
#   8.586 11.01   9.403  7.707  8.565 10.8    9.869  9.089  9.528  8.502
#   9.388 10.09   9.653  8.882  7.435 11.32  10.41  10.46  11.77   7.983
#   5.481 10.73   6.118 10.99   8.322  9.435  7.268  7.518  5.336  6.604
#   8.579  7.583 10.62   6.523  7.98   8.043 10.65   9.093  4.96   9.149
#  10.19   6.937  8.671  8.712  8.32   7.278  7.595  9.176  7.423 10.
#   6.931  9.386  7.834  6.601  7.576  6.437  7.211  9.168  9.849 10.15
#   9.348  9.563  8.944  9.554  9.207  8.901  7.979  8.952 10.52   7.11
#   8.061 11.52  11.78   7.393  6.566  7.283  9.575 10.51  11.53   9.223
#   8.802  9.653  8.364  6.957  7.876  7.89  10.52   9.053  9.182  7.18
#  11.04  10.71   9.972  6.489  8.341  8.928  8.894  8.636  7.679  7.733
#   9.818  7.662  8.624  8.932  9.84  10.37   8.925 12.02  10.47   8.588
#   9.904  7.208 10.42   9.147  7.839  7.702  9.128  7.663  8.197  7.967
#   9.471 11.93  10.27   8.214  7.616  7.572 10.12  10.43  10.56   9.682
#  10.64   6.806  7.061  9.413  7.952  8.31   7.646  7.43   8.614  8.25
#   9.9    7.97   7.716]
# [12.    10.44  10.06   8.827  6.732  9.207 11.9    9.71   7.797  9.745
#   8.782  6.754  9.828  6.55   7.845 10.18   7.949  8.456  8.81   6.772
#   9.971  8.565  7.589  7.306  7.375 10.22   6.056  9.314  6.533  8.891
#   9.58   8.215  7.086  6.617 10.57  11.74   8.946  6.703 10.06   8.92
#   7.187  6.094  5.714  6.479  7.584  8.881  6.838  8.413  6.364  5.577
#   9.567  9.018  6.674  7.922  6.78   6.716  9.14   8.58   8.988 11.3
#   7.79   9.208  9.409  7.698 11.47  10.98   7.901  7.559  8.606  8.013
#   8.929  8.844  5.675  8.963  9.796  7.346  9.189  7.843  5.685  6.46
#  10.41   9.912  8.405  8.074  7.955 11.82   8.479  8.937  7.974  9.719
#   9.688  9.699  9.743 10.01   7.283 10.71  10.71  11.17  11.6    9.013
#   5.476 10.43   6.158 10.39   7.241  9.526  7.591  7.35   5.319  6.393
#   7.596  5.835  8.831  6.531  9.133  7.134 10.42   9.424  5.383  8.93
#  11.21   6.927  7.1    9.316  8.71   7.4    8.001  9.97   6.956 10.04
#   7.112  9.742  7.83   5.964  8.642  6.376  6.596  9.18   9.796 11.41
#   8.919 10.24   9.963  9.625  8.909  8.14   7.886 10.13  10.63   6.75
#   8.05  10.93  11.96   7.475  6.822  8.385  9.489 10.41  10.34  10.47
#   9.527 10.45   9.295  7.331  7.717  7.159 10.04   8.627  9.05   7.684
#  11.83  10.98  10.04   5.411  8.236  9.924  8.454  8.249  7.619  7.401
#   9.133  8.277  8.535  7.99   9.086 10.62   9.144 12.34  10.37   8.306
#   9.696  6.974 10.69   9.036  8.702  7.644  8.335  7.442  7.922  7.661
#   9.082 12.05  10.79   7.166  7.06   7.641  9.76  12.96  11.48   9.318
#  10.8    5.69   7.118 10.38   7.551  7.394  7.476  6.705  8.408  7.805
#   9.386 11.67   7.368]
# [12.56   9.975  9.164  7.274  7.118  8.957 11.77   9.53   8.262  9.492
#   8.914  7.386  9.832  7.932  8.156 11.28   8.836  8.254  7.792  5.989
#  10.2   10.39   9.072  6.933  6.751 10.5    5.938  6.313  5.888  8.841
#   9.471  8.068  7.068  6.714 10.46  11.29   8.186  6.535 10.24   8.384
#   6.349  6.291  5.542  5.7    6.927  9.545  6.568  8.537  6.93   5.743
#   9.283  8.418  6.547  6.494  8.098  6.924  9.699  9.144  8.474 11.44
#   7.571  9.478  9.538  8.876 10.92  10.19   8.552  5.468  8.591  7.703
#   9.424  9.285  5.884  6.743  9.636  7.066  9.503  7.461  5.084  6.503
#   9.348  9.706  8.671  7.795  7.744 11.81   7.965  9.971  8.772  9.212
#   9.666  9.314  9.683  9.646  7.734 10.46  10.46  10.72  11.62   9.888
#   5.213 11.14   6.788 10.54   8.338  8.858  7.957  6.485  6.289  6.224
#   7.158 10.19  10.09   6.101  7.788  7.122 10.37   8.86   4.838  9.057
#  11.09   7.46   7.415  9.78   8.216  6.961  7.751  9.47   6.234 10.69
#   6.812  8.981  7.369  6.149  8.74   5.985  6.875  8.704  9.133 10.61
#   8.284 10.15   9.674  9.727  9.187  7.595  7.599  9.162  8.775  7.527
#   8.083 11.99  12.38   6.567  6.727  7.934  9.529  9.989 10.76   9.945
#   8.982 10.83   8.524  7.558  7.977  7.379 10.17   8.637  8.644  7.075
#  10.76  11.11  10.13   5.62   8.65   9.497  8.656  7.125  7.595  7.921
#   9.009  7.748  7.631  9.774  9.146  9.604  9.434 11.26  10.31   8.444
#   9.415  7.198  9.751  8.89   8.179  7.174  8.523  7.336  8.361  7.65
#   8.678 11.62  10.68   6.984  7.543  7.208  9.711 11.66   8.506  9.252
#   9.682  5.748  5.861 10.27   7.657  7.236  6.982  6.382  8.022  7.562
#   9.02   6.655  7.078]
# [11.02  10.7    9.433  7.87   6.166  9.364 10.38   9.177  6.46   9.334
#  10.36   6.906  9.47   8.048  7.518  9.625  8.145  8.275  7.553  6.037
#   9.41   6.196  8.089  8.633  6.389 10.84   7.201  9.025  6.232  8.063
#   9.551  8.666  7.472  7.226  9.818 11.63   8.765  6.871 10.42   9.021
#   8.582  9.62   5.25   5.603  5.938 10.13   6.341  8.954  5.927  6.974
#  10.01   9.583  6.771  7.605  6.76   5.081  8.76   7.426  8.16  11.22
#   7.128 10.31   8.858  7.086 10.19  10.68   6.98   4.895  7.312  8.953
#   7.668  9.319  5.894  8.323  9.186  6.78   8.573  7.022  5.05   6.259
#   8.503 11.85  11.51   7.191  8.222 11.21   9.137  8.502  6.545 11.88
#   9.327  8.777 10.11   9.606  8.628 10.86  10.25  11.92  11.29   7.985
#   5.579 10.03   8.096 13.06   7.775 10.53   7.108  7.694  6.057  6.5
#   6.353  6.28   8.454  5.692  8.254  6.514 11.9    9.258  4.371  9.03
#  11.52   6.829  7.519 10.13   8.151  7.163  7.322  9.836  6.823 10.52
#   8.021 10.87   8.295  5.143  7.306  5.884  6.892  8.509  9.177 10.26
#   8.115 10.14   9.813  9.028  9.103  7.625  7.483  9.868 10.92   7.384
#   8.742 10.5   11.84   6.173  7.802  9.306  9.159 10.23  12.34  10.32
#   9.238  9.399  9.094  7.493  8.024  7.406 11.1    8.32   9.945  7.035
#  11.55  10.85   9.674  5.174  8.118 10.09   7.768  8.397 10.18   9.165
#   9.245  8.353  8.692  8.848  9.543 11.69   9.145 12.85  10.27   9.076
#   9.088  7.507 10.66   9.647  8.471  7.952 10.54   7.427  7.306  8.487
#   9.571 13.04  10.9    7.319  6.569  9.023 10.1   10.73  12.05   8.138
#   9.58   4.772  6.197 10.02   7.644  6.77   6.804  5.22   7.703  8.154
#   8.729  6.944  7.5  ]
# [12.18   9.854  9.006  9.084  6.242  8.344 14.29   7.313  9.279  8.221
#   6.776  7.725 10.18   9.204  8.032  9.152  8.628  8.521  8.738  6.823
#  10.38   7.634  8.154  7.467  7.564 11.18   6.548  6.323  7.907  7.608
#   9.386  7.755  7.469  7.937  9.273 10.69   8.651  8.06  11.66   9.284
#   7.36   5.467  5.936  5.792  6.938  9.291  7.1    8.376  7.239  6.238
#   9.344 10.15   7.56   9.725  9.291  7.652 11.     7.267  9.276 11.87
#   6.876  9.168  8.196  7.321  8.93  12.02   9.083  8.15   8.904  8.297
#  10.08   9.112  5.35   8.53   9.776  7.495 10.6    8.076  5.696  6.402
#  10.65  10.26   7.746  7.006  8.643 11.37  10.05   7.935  6.899  8.597
#   9.194  9.444 10.23   9.09   8.447  9.961  9.686  8.614 10.57   9.768
#   5.502 11.21   6.216  9.439  8.858 10.98   7.148  8.177  6.008  7.726
#   7.452  4.97  10.69   6.412  8.988  6.31  10.46   7.749  5.783  8.576
#  11.5    7.153  7.266 10.96   8.475  6.929  7.97  10.1    6.55  10.2
#   6.454  9.811  8.581  8.34   9.174  5.944  7.331  8.295 10.28  11.8
#   8.444 10.36  10.42   8.322  9.294  7.862  7.661 10.42  11.33   7.348
#   8.244 12.02  11.54   5.724  9.768  8.888  9.117  8.246 12.76  10.36
#   8.8    9.714  8.658  7.342  8.278  6.894 10.37   8.238  8.439  6.997
#  11.39  11.16   9.397  6.767  8.517 10.41   8.13   6.855  8.066  7.439
#   9.439  7.662  8.131  7.557  8.962 10.16   8.894 11.48  10.42   8.279
#   8.756  7.492 10.99   9.601  9.037  7.633  9.047  8.335  8.954  7.874
#   8.527 11.38  10.8    7.254  6.771  8.302 11.02  10.73   9.049  8.949
#   9.551  6.486  7.573  8.864  6.238  6.765  7.03   7.511  7.814  8.404
#   8.75   6.636  7.56 ]
# [ 9.599 10.15   7.316 10.93   5.745  8.258 13.83   8.95   7.047  9.867
#   7.784  6.495  9.434  8.534  8.031  9.72   8.624  9.673  8.479  8.029
#  10.18   7.136  8.406  6.746  7.508 10.51   5.485  7.025  6.343  8.056
#   8.922  7.409  6.577  6.199  9.486 11.02   8.849  8.464 10.08   8.486
#   7.326  4.982  5.897  5.602  8.27   9.538  6.531  8.553  6.069  6.121
#   8.715  8.444  6.771  8.41   8.938  8.238  9.954  8.42   8.21  11.72
#   8.541 10.34   9.764  6.788  7.684 11.66   8.617  5.781  8.867  8.178
#   8.343  9.875  4.148  8.481  9.513  6.034 10.18   7.724  4.945  6.196
#   8.968 10.97   7.798  7.312  8.096 11.47  11.33   9.538  6.72   9.1
#   8.914  9.095 10.01   8.898  8.192 10.75   9.419 10.47  11.03   9.025
#   5.673 12.17   5.965 11.85   7.419 10.63   7.383  7.603  5.92   6.562
#   6.919  4.134  9.957  5.38   7.671  6.807 11.51   8.624  3.937  8.5
#  11.42   6.898  7.213 10.28   9.448  8.425  7.731 11.14   6.009 11.27
#   5.664  9.718  7.713  4.829 10.7    5.131  7.192  8.44  10.55  10.7
#   8.617 10.84   9.751  8.744  8.514  7.039  7.31  11.27  11.66   7.933
#   9.429 12.93  11.91   6.176 10.65   7.806  8.615  9.053 12.18   9.713
#   8.835  9.615  8.769  7.619  9.076  7.415 10.09   7.804  8.797  6.281
#  10.14  10.86   9.454  4.555  7.84  10.88   7.726  6.708  8.116  8.074
#   9.128  9.237  8.23   7.943  9.091 11.12   9.327 13.28  11.29   8.732
#   8.687  7.873 12.94  10.52   9.001  7.198  8.375  8.242  8.391  6.282
#   8.337 11.88  10.17   7.341  7.674  6.926  9.736 10.68   9.164  8.048
#   9.411  4.909  6.635  9.611  7.004  6.9    6.617  8.967  7.176  7.223
#   8.863  6.13   6.955]
# [11.26   9.777  8.038  8.607  6.938  8.759 12.53   8.608  7.007  8.614
#   9.751  9.988  9.176 10.56   7.716  9.85   7.737  8.806  8.651  5.401
#  10.02   8.711  7.967  7.612  6.889 10.84   7.644  6.056  6.844  7.543
#   8.998  7.628  6.327  6.194  9.693 11.51   8.32   7.635 11.25   9.44
#   9.073 10.04   5.898  6.406  6.894  9.978  6.85   9.947  6.773  5.667
#  10.35   9.072  6.069 10.04   6.615  6.459  9.214  8.159  8.114 11.44
#   6.646  9.534  8.237  6.826 11.05  10.55   6.909  5.033  8.828  9.244
#   8.647 10.72   5.934 10.44   9.971  7.713 12.13   8.781  5.837  7.603
#   9.885 11.96   7.737  6.605  8.176 11.08  10.66   8.316  8.303  9.232
#   9.086  8.821 11.04   9.629  9.234 10.74   9.522 10.19  10.96   8.472
#   5.26  11.49   6.025 11.52   7.086  9.874  6.581  8.704  5.912  6.08
#   6.544 11.24  11.39   5.92   8.042  6.418 11.26   8.389  4.585  8.632
#  11.29   7.513  6.802 10.44   8.475  8.352  7.334  9.732  5.893 10.14
#   6.837 10.66   7.297  5.404  8.197  5.334  6.516  8.09   8.884  9.935
#   8.3   10.44   9.305  8.818  9.333  7.669  7.026 10.19  11.21   7.44
#   7.863 10.04  12.66   6.793  8.938  6.88   8.492  9.9   12.64   9.867
#   9.123  9.711  9.224  7.812  7.937  8.087 10.17   7.976  9.518  7.056
#  11.76  11.24   9.238  6.746  8.627 11.17   7.426  9.316  8.527  8.415
#   8.934 10.1    8.259  8.685  8.968 11.24   9.51  13.66  10.91   9.076
#   8.721  7.636 12.38  10.15   9.088  6.905  9.903  7.511  8.114  8.413
#   8.302 12.97  10.3    7.424  6.329  7.937 11.35  10.37  11.74   8.282
#  10.05   5.163  6.037 10.05   7.412  6.444  6.626  5.171  7.464  6.836
#   8.945  6.53   8.087]
# [ 9.689 10.36   8.014 10.42   6.602  9.429 12.15   8.84   6.389  9.505
#  11.43   7.402  9.178 10.29   7.688 10.06   8.322  8.493  8.968  6.48
#   9.116  8.838  8.895  7.807  6.343 11.01   7.588  9.254  6.406  7.661
#   9.717  8.135  7.049  8.19   9.607 11.12   8.503  8.193 10.86   9.222
#   8.391  5.962  5.741  6.368  7.363  9.565  6.876  9.667  5.862  5.328
#   9.41   8.904  6.336  9.791  7.604  6.325  7.833  8.345  7.742 11.21
#   8.126 10.05   8.94   7.055 10.65  10.77   7.244  5.416  8.471  8.726
#   8.292  9.494  5.478  9.876  9.378  6.266  9.408  7.088  5.23   5.69
#   8.782 11.23   7.421  6.872  7.604 10.31  10.75   8.85   7.591  9.073
#   9.093  9.124 11.05   9.168  9.245 10.99   9.426  9.722 10.9    8.217
#   5.555 10.93   5.577 12.27   6.722  9.323  6.709  7.946  5.801  5.949
#   6.199  9.847 11.01   5.876  6.751  6.456 10.3    8.532  4.942  8.695
#  11.05   6.664  7.1    9.972  8.157  7.711  7.254  9.877  6.186  9.169
#   6.471 10.47   6.787  5.586  7.27   5.64   6.962  8.054  9.487  9.641
#   8.463 11.01   8.813  8.808  9.391  7.785  7.399 10.73  12.08   7.723
#   8.765 11.35  12.22   5.87   7.417  8.22   9.1   10.68  10.65   9.962
#   9.34  10.31   9.47   8.202  9.184  8.006 10.25   8.122  9.266  6.816
#  10.13  11.16   9.109  5.824  7.691 10.18   7.478  7.8    8.877  8.541
#   9.09   9.424  8.704  8.741  9.494 11.84   9.566 13.39  10.98   9.765
#   8.704  8.13  12.58  10.67   9.68   8.962 10.39   6.52   8.299  8.2
#   8.845 12.21   9.904  7.367  7.008  7.559  9.746  9.781 12.01   8.116
#   9.676  5.359  6.553  9.951  7.908  6.607  6.922  5.393  8.171  8.396
#   8.388  6.288  8.427]
# [10.5    9.3    6.77   8.032  5.959  8.66  12.26   7.943  6.789  8.565
#   8.767  8.328  9.253  9.513  8.131  9.578  8.628  6.946 10.84   7.639
#   9.491  8.738  9.153  7.394  7.563 10.85   4.705  5.713  6.202  7.301
#  10.19   7.572  6.968  6.476  9.386 11.3    8.454  7.691 10.82   8.847
#   8.203  5.413  5.445  5.672  7.313  9.93   6.862  8.202  6.538  6.637
#  10.1    8.466  7.016  9.066  7.903  6.325  8.807 10.01   8.632 12.
#   6.39   8.533  8.264  8.359 10.62  14.2    8.488  5.362  9.161  7.348
#  10.69   9.167  5.043  5.505  9.105  6.686  9.13   7.501  5.184  6.787
#   8.843 11.25   7.614  7.362  8.798 11.86   9.817  9.547  7.128 10.78
#   8.954  8.767 10.69   9.219  8.336  9.665  9.553 10.1   10.56   9.525
#   5.074 11.79   8.579 12.63   7.16  10.45   7.106  7.589  6.025  6.377
#   6.489  5.744 11.22   7.18   8.496  6.245 11.09   8.354  5.361  9.192
#  11.82   6.732  7.798 11.67   8.646  7.482  7.107 10.42   6.488 10.
#   5.724 10.16   6.207  5.703  7.616  5.624  7.318  8.657 10.19  10.82
#   7.714 10.16   9.585  7.975  8.956  7.18   7.228 10.79  10.11   6.602
#   8.261 10.24  12.09   5.705  7.332  6.748  9.422  8.557  9.608 10.6
#   8.813 10.14   9.204  7.597  8.607  7.964 10.76   8.173  9.647  6.817
#  11.26  10.93   9.141  6.312  7.553 10.34   7.648  7.931  8.055  7.588
#   9.625  8.715  7.444  7.722  8.995 10.47   8.806 12.22  10.5    8.046
#   8.418  7.581 11.08   9.086  8.361  7.465 10.17   7.82   6.829  7.198
#   8.676 12.42  12.41   6.746  6.308  7.454 10.27  12.21  12.48   8.115
#   9.461  9.261  6.707  9.445  7.497  6.568  6.62   8.073  7.46   6.78
#   8.246  6.446  6.8  ]
# [ 9.733 10.2    8.508  9.491  5.954  8.744 14.32   8.654  8.442  8.06
#   7.698  8.378  9.376  8.563  8.474  9.754  8.19   8.346 10.4    6.578
#  10.43   6.816  8.474  7.965  6.962 11.29   6.488  8.327  7.256  7.546
#   9.976  7.691  6.696  8.758  9.648 10.88   8.295  8.585 11.06   8.946
#   7.851  6.052  5.959  6.02   7.217  9.625  6.651  7.956  6.786  6.901
#   9.606  9.517  7.574  9.387  8.752  7.894 10.66   7.23   8.564 11.58
#   6.338 10.08   7.566  7.146  8.06  12.02   7.062  6.942 10.13   9.414
#  11.82   9.658  5.928 11.31  10.17   7.712 11.1    8.43   5.743  6.91
#  10.28  11.25   8.473  6.866  7.95  10.5    9.688  7.253  7.534  9.403
#   8.744  8.681  9.892  8.506  7.988  9.934  9.264  8.122 10.55   9.2
#   5.473 11.94   6.068 11.08   8.346 10.34   7.745  7.459  5.394  6.692
#   6.975  4.94  10.33   6.394  8.828  6.176 11.31   8.426  5.163  9.022
#  11.51   7.914  7.824 10.86   9.37   7.056  7.442 10.83   6.407 10.11
#   6.17  10.48   8.496  5.868  9.59   5.629  7.148  8.131  9.896 11.88
#   8.726 11.19   9.361  8.434  9.074  8.09   7.524 11.27  11.43   7.485
#   9.011 11.21  11.29   5.906 11.46   7.4    8.144  8.425 12.13  10.07
#   8.856  9.232  9.285  7.826  8.909  7.867  9.703  8.145  9.126  6.942
#  11.31  11.32   9.448  6.582  8.064 10.39   7.792  7.367  7.679  7.416
#   9.16   8.159  7.652  7.625  8.052 10.94   8.782 12.24  11.32   7.942
#   8.582  6.933 11.34   9.825  8.51   7.344  9.094  7.883  7.882  8.083
#   8.496 11.92  10.39   9.535  6.41   7.536  9.509 10.55  11.58   8.27
#   9.882  5.65   7.976  9.725  7.826  6.639  6.738  9.178  7.505  8.107
#   9.064  6.831  6.908]
# [12.18   9.546 10.07  10.25   7.292  8.49  12.07   8.269  7.301  7.979
#  10.43   7.693  9.593  9.363  7.802 11.22   7.914  8.666  8.706  7.226
#  10.36   9.81   8.81   8.468  7.354 10.55   7.104  8.143  6.461  7.907
#  10.13   8.712  7.766  7.431  9.322 11.66   8.802  8.492 10.88   9.311
#   8.381  5.711  5.445  6.902  6.575 10.18   6.99   8.525  6.275  5.414
#  10.1    9.092  6.074  7.059  7.322  5.748  9.899  8.587  8.279 10.35
#   6.48   9.244  8.396  7.276 11.2   10.17   7.788  7.627  8.634  8.799
#   9.727  9.578  4.996  7.701  9.498  7.304 10.78   8.016  5.034  6.5
#  10.82  10.86   8.399  7.916  7.226 12.17   9.109  8.949  9.268 11.65
#   9.097  9.972 10.11   8.846  7.963 10.94   9.038 11.1   10.28   9.335
#   5.875 10.37   5.707 12.1    8.18   9.916  8.027  9.277  6.332  6.747
#   5.976 10.77   9.795  7.638  9.156  5.885 10.46   8.594  4.415  9.139
#  11.1    7.509  7.77  10.29   8.782  7.825  7.491  9.864  6.051 10.08
#   6.022 10.16   6.588  6.088  8.715  6.042  6.786  8.131  8.919 10.61
#   7.99  10.55   9.331  8.407  9.263  7.371  7.441  9.774  9.281  7.582
#   8.44  11.04  11.4    6.17   7.126  6.94   8.527  9.1    9.765 10.63
#   8.478 10.22   9.178  6.658  7.602  7.71  10.34   7.928  9.061  7.46
#  10.97  11.87   9.42   5.323  8.115  9.975  7.726  9.331  7.915  8.315
#   9.093  8.29   8.012  7.71   7.967 10.46   8.986 11.15  10.85   8.105
#   8.564  6.487 10.08   9.446  8.128  7.894 10.08   7.391  7.54   7.598
#   8.914 11.96  10.04   7.152  6.574  7.444 10.19  10.09  10.96   7.895
#   8.86   5.263  6.794 10.1    8.668  6.229  6.315  5.698  7.44   8.02
#   7.734  6.362  9.232]
# [ 9.613 10.17   8.403 10.05   6.616  8.835 12.68  10.3    7.605 10.17
#  10.62   7.334  9.873  8.228  7.624  9.918  8.324  7.988  8.922  6.248
#  11.     7.058  7.532  7.315  7.17  10.47   5.198  9.782  6.248  8.823
#   9.724  7.542  6.273  7.6   10.53  11.1    8.528  7.291 10.2    8.572
#   8.522  7.018  5.364  5.62   6.964  9.412  6.216  8.134  6.556  6.45
#   9.725  9.132  6.163  7.255  8.091  6.616  9.563  9.243  8.394 11.85
#   7.334 10.16   9.355  6.901 11.06  11.32   7.709  5.565  8.566  8.424
#   9.525  8.792  4.889  9.753  9.375  6.812  9.32   7.669  5.092  6.194
#   9.904  9.468  8.541  7.915  8.434 11.01   9.288  9.047  7.717  9.493
#   9.418  9.425 10.39   8.93   8.341 11.34  10.14  12.49  11.6    8.371
#   5.533 11.16   5.725 12.42   7.661  9.811  6.764  7.68   5.779  6.321
#   7.63   4.501  9.287  5.344  7.876  6.855 10.65   8.981  4.954  9.718
#  10.73   7.748  7.519 11.12   8.18   8.453  7.388  9.86   6.473 10.3
#   6.738 10.25   7.845  5.499  7.671  5.449  6.739  9.096  9.316  9.46
#   8.9   10.21   9.268  9.077  8.494  7.391  7.317  9.764  9.627  6.978
#   8.418 11.54  12.57   7.487  7.933  8.604  9.01   9.798 10.69   8.999
#   8.567  9.523  8.822  7.36   7.686  7.537 10.08   8.61   9.176  6.956
#  10.44  10.82   9.796  6.507  7.939 10.23   8.182  8.783  8.014  7.643
#   8.812  9.048  7.869  8.114  8.598 10.58   9.552 12.75  11.69   8.832
#   9.42   7.469 11.94   9.305  8.586  7.114  8.513  7.478  7.699  6.696
#   8.725 11.81  12.48   7.804  6.848  7.419  9.836  9.919 11.66   9.108
#  10.9    8.389  6.221 10.09   8.099  6.949  6.912  7.724  8.18   7.496
#   8.483  9.298  6.834]
# [10.48   9.33   8.221  9.458  7.955  9.365 12.27   8.616  8.001  9.135
#   6.726 11.37   9.9   10.53   8.845 12.97   8.524  8.709  9.264  7.135
#   9.631  6.072  8.536  8.237  8.113 10.97   6.35   9.721  6.993  7.863
#   9.503  7.669  6.872  8.049  9.571 11.01   8.724  7.462 10.3    8.935
#   8.791  6.423  6.368  6.042  6.758  9.456  8.015  8.356  6.587  6.062
#  10.51   8.99   7.635  9.324  8.702  7.196  8.074  8.224  8.163 10.88
#   8.618  9.588  8.742  7.495  9.818 12.54   7.959  7.013  8.543  9.145
#   9.566 10.18   6.288  6.498  9.766  7.955 10.52   8.345  6.616  6.167
#  10.11  11.52   7.699  7.916  9.704 12.36  10.21   9.434  8.988 10.13
#   9.089  8.632 10.99   9.546  9.773 10.18   9.8   10.51  10.74   9.978
#   6.251 10.71   6.49  12.     9.104 11.02   7.391  7.07   6.603  6.922
#   6.632  6.062 11.19   6.607  7.792  7.143 11.77   8.812  5.953  9.475
#  11.68   6.977  8.114 10.13   9.962  9.755  8.119 11.08   7.745 10.3
#   6.656  9.691  8.247  6.224  9.436  6.439  7.44   8.308 10.42  10.59
#   9.554 10.8    9.288  8.59   9.758  7.415  7.775 11.54  12.58   7.683
#   9.28  12.81  11.67   6.486 12.43   8.894  8.502  9.692 12.6    9.293
#   8.365  9.976  8.859  7.401  8.139  8.023 11.06   8.503  9.216  7.309
#  10.63  10.46   8.93   6.764  8.239 10.74   7.839  7.273  8.188  7.271
#   8.77   8.236  8.147  8.315  8.446 10.1    9.438 12.65   9.866  8.012
#   8.53   7.353 11.51   9.35   8.161  7.149  9.334  7.821  9.204  7.122
#   8.236 11.57  10.64   7.199  7.289  7.333  9.465 10.47  11.07   8.307
#  10.3    6.122  9.549  9.192  7.459  7.185  7.409 10.02   8.074  7.61
#   8.45   8.881  7.259]
# [ 9.043 10.26   7.469  7.93   8.369  8.981 10.67   9.32   5.64   9.028
#  10.17   8.167  9.94   9.247  7.55  10.76   8.442  6.704  9.37   6.241
#   9.616  8.434  8.221  6.638  6.837 10.3    5.611  6.624  6.946  8.878
#  10.85   8.812  7.325  7.389 11.06  11.07   8.502  8.622 10.68   9.493
#   9.202  5.593  5.616  4.606  6.884  9.92   6.408  9.016  6.041  5.039
#  10.32   8.517  5.949  8.287  7.104  6.075  9.186  7.61   7.23  11.3
#   6.715 10.38   8.826  7.372 13.16  10.32   7.332  5.356  8.38   8.879
#  10.56   9.022  6.189 10.55   9.522  7.601 10.52   7.36   4.696  6.47
#   8.536  9.363  9.024  7.46   8.18  10.46   9.731  8.358  9.521  8.611
#   9.34   9.32  10.07   8.385  9.469 10.36  10.08  12.45  11.21   8.564
#   5.272  9.338  9.182 11.07   8.808  9.259  6.246  7.563  4.426  6.559
#   6.509  5.796  9.821  6.2    8.193  6.976  7.527  9.334  4.665  9.213
#  11.3    7.042  7.323  9.944  8.694  7.221  7.304  9.352  6.371  9.831
#   7.853 10.4    6.777  5.043  8.242  5.517  6.946  8.644  8.734  9.637
#   8.48  10.42  10.44   9.36   8.791  8.146  7.815  9.925 10.63   7.706
#   8.85   9.739 11.17   6.48  10.52   8.812  9.307 10.48  12.41  10.5
#   9.301 10.21   9.41   7.618  8.98   8.03   9.802  8.441  9.854  7.788
#  11.25  10.94   9.767  6.584  8.309 10.12   7.84   9.612  7.85   8.41
#   9.195  8.502  8.442  8.303  8.435 11.11   7.93  12.07  10.91   9.044
#   9.244  6.866 10.51   9.182  8.716  8.182  9.97   7.997  7.2    8.415
#   8.762 12.2   10.49   7.52   7.094  7.531 10.82  10.83  10.48   8.749
#   9.997  4.875  5.197 10.73   8.34   6.825  6.652  4.886  8.848  8.434
#   8.39   7.421  7.407]
# [ 9.905 10.52   8.061  9.919  6.768  9.707 13.5    9.136  6.711  9.408
#   9.145  7.895  9.322  8.048  7.274  7.608  8.219  7.602  7.634  5.552
#  10.09   8.324  7.269  6.716  7.84  11.2    6.724  6.959  5.732  8.343
#   9.8    8.296  7.674  7.359  9.926 11.35   8.43   6.283 10.3    8.816
#   8.969  7.183  6.103  5.874  7.722 10.49   7.136  9.659  5.824  6.32
#   9.602  9.218  6.522  8.573  7.966  5.629  7.1    7.831  8.168 11.8
#   6.716 10.66   9.226  7.033 11.12  10.3    7.313  5.589  8.595  8.44
#   8.128  9.832  4.323  9.962  9.326  6.13  10.2    6.442  4.923  7.172
#   8.124 11.58   7.951  7.095  8.545 10.86   9.811  8.202  8.293  8.768
#   9.743  9.209 10.27   9.938  9.832 11.39  10.24  11.47  11.66   9.094
#   5.352  9.841  5.839 13.19   7.26   9.573  6.381  7.336  5.504  6.049
#   6.72  10.03  10.32   5.971  7.533  6.995 11.18   9.     4.581  9.05
#  11.17   7.412  7.243 10.28   8.287  7.429  8.216  8.88   6.953  9.82
#   7.231  9.21   6.355  5.611  7.608  5.742  7.765  9.292  9.384  9.969
#   7.975 10.58  10.36   9.247  9.411  7.994  7.929 10.59  10.5    7.618
#   8.39  10.81  12.43   6.406  6.148  9.024  9.488 10.71  10.18  10.86
#   9.605  9.23   8.657  7.228  7.795  7.264  9.849  8.653  9.002  5.446
#  10.68   9.848  9.654  5.124  7.873 10.16   7.72   8.192  9.377  8.569
#   9.569  9.229  8.209  7.788 10.02  12.25   9.274 12.63  10.59   8.999
#   9.808  8.249 11.34  11.25  10.38   8.913  8.061  7.407  7.678  7.05
#   9.012 13.88  10.77   6.85   7.453  7.434 10.19  10.5   11.93   8.389
#  10.52   5.136  6.47   9.865  7.216  6.57   6.938  5.562  7.986  8.081
#   8.938  6.911  7.04 ]
# [10.28  10.14   8.278  8.74   7.984  9.392 12.21  10.83   6.764 10.54
#   9.881  7.474  9.698  7.702  7.466  9.414  8.462  7.84   8.564  7.245
#   9.732  8.895  8.473  8.376  8.234  9.877  6.568  7.71   7.464  9.843
#   9.619  8.369  6.606  8.336 11.27  11.08   7.242  7.738  9.507  8.126
#   7.264  7.162  6.124  5.962  6.773  8.946  6.593  8.776  8.049  6.255
#  10.72   9.05   7.486  7.275  6.946  5.525  7.65   8.269  9.016 11.54
#   8.384  9.474  9.505  7.819 11.27  10.22   8.164  8.092  9.646  9.79
#   9.479 10.03   5.6    9.957  9.624  8.097 10.55   7.91   6.284  7.221
#   8.422 11.27  10.4    7.754  8.39   9.949  7.893  7.398  8.158  8.036
#   9.948 10.09  10.02   8.794  8.501  9.747 10.79  10.33  12.34   8.24
#   5.904 10.18   7.071  9.954  7.338  9.068  7.569  8.144  5.883  6.699
#   8.685  5.528 10.21   7.049  7.299  7.568  9.915  9.651  5.509  8.923
#   9.623  6.937  6.982  9.384  8.152  7.508  8.416  8.831  6.984  9.728
#   7.629  8.772  7.812  5.779  7.993  6.429  7.488  9.702 10.03   9.766
#   9.393  9.279  8.828  9.539  8.848  8.581  8.209  8.537  9.495  7.782
#   8.281 10.32  11.29   7.516  6.863  8.18   9.367 10.73  11.08   9.195
#   8.641  8.586  8.128  6.814  7.688  7.796  9.467  9.16   9.308  7.762
#  10.66   9.987  9.992  5.997  7.876  9.415  8.019  9.309  6.956  8.103
#   9.465  8.897  8.517  9.886  9.231 10.57   8.566 11.99   9.756  9.35
#   9.964  7.156  9.769  9.059  8.489  7.405  6.783  8.196  8.222  7.074
#   8.997 11.18  10.78   8.162  7.819  8.047 10.04   9.812 10.62   9.694
#  11.02   6.556  6.548  9.001  7.514  8.055  7.656  7.92   9.187  8.636
#   9.074  8.688  8.335]
# [ 9.94   9.816  7.977  7.809  6.788  9.007 13.74   9.19   6.666  9.542
#  11.71   6.768  9.636 10.29   7.953  9.852  8.05   9.531  9.503  7.077
#   9.357  7.673  8.802  6.463  6.294 10.27   6.644  5.964  6.813  7.663
#   9.862  8.202  7.224  8.872  9.64  11.18   8.241  7.065 10.48   9.463
#   7.431  5.975  5.696  5.134  7.059  9.357  7.233  9.258  6.581  5.523
#  10.2    8.807  7.288  9.137  7.81   5.64   8.683  7.821  7.39  11.44
#   6.715  8.949  8.878  7.315 11.97   9.869  7.557  5.83   9.497 10.68
#  10.11  11.41   5.697 12.47  10.29   9.18  12.05   8.235  5.709  7.484
#  10.4   10.74   9.239  6.814  7.93  10.81  10.6    9.441  8.945  9.767
#   8.892  8.586 10.64   9.185  9.486 10.17   9.644 10.32  10.68   9.097
#   6.098 11.7    6.12  11.88   7.458  9.971  6.811  8.409  6.672  6.818
#   6.737  7.134 10.28   6.49   7.619  6.748 11.48   8.358  5.487  9.524
#  11.33   6.418  7.678 10.76   8.163  6.998  7.285  9.396  6.098  9.514
#   6.659 11.2    7.342  5.262  8.017  6.222  6.908  8.144 10.05   9.639
#   7.887 10.36   8.905  8.976  9.414  7.726  7.285 10.74  11.05   7.746
#   7.659 11.39  12.17   5.815  5.978  7.307  8.499  9.457 11.32   9.361
#   8.886  9.982  9.392  8.38   8.066  8.356 10.72   8.376  8.949  7.045
#  11.32  10.92   9.192  6.516  9.135 10.93   7.787 10.02   7.884  7.375
#   9.705 10.82   8.038  8.822  8.988 10.71   9.444 13.22  10.77   9.143
#   9.052  7.331 11.33   9.711  9.138  7.246 10.05   7.469  8.482  7.714
#   8.684 12.48   9.554  7.046  6.922  8.062 10.87   9.575 11.62   8.448
#  11.18   5.571  6.403  9.317  7.767  6.97   7.08   6.012  8.033  7.357
#   9.077  6.405  7.97 ]
# [ 9.876  9.85   8.232  7.601  7.01   8.894 12.31   9.014  6.823  8.538
#   8.186 10.74   9.43   9.884  8.436  9.595  9.229  8.845  9.486  7.575
#  10.59   8.443  8.243  7.55   7.645 11.35   4.808  7.704  7.622  8.046
#   9.894  8.07   7.581  6.932  9.573 11.75   8.514  8.459 11.8    9.04
#   9.163  6.536  5.418  6.328  6.37  10.15   6.389  8.089  5.923  5.51
#   9.658  8.708  6.651  8.112  8.343  5.995  9.719 10.12   8.687 12.04
#   6.629  9.606  8.323  7.216 10.8   11.36   6.693  7.1    9.711  8.46
#   9.435  9.952  5.151  8.266  9.854  7.96  10.4    8.387  5.971  6.927
#  10.56  12.18   8.86   7.164  8.157 11.43  10.42   8.974  7.148  8.914
#   9.184  9.207  9.547  8.84   7.549 10.87   9.336  9.935 10.93   8.72
#   5.031 10.77   5.835 11.75   6.624  9.979  7.314  7.791  5.774  6.208
#   6.699  5.32  12.56   6.082  8.557  6.637 11.17   8.95   4.818  8.53
#  11.25   7.049  7.587 10.35   8.808  8.261  7.282  9.682  6.142 10.07
#   6.603  9.343  7.251  7.052  8.023  6.04   6.441  8.987  9.895 10.66
#   8.258 10.14   9.183  8.741  8.791  7.376  7.248 10.04  10.73   7.26
#   8.687 10.09  11.14   7.995  7.861  7.781  8.352  8.982  9.535 11.08
#   9.876 10.47   9.826  7.985  8.744  7.622 10.6    8.381  9.406  7.181
#  11.24  12.19   9.782  7.118  8.304 10.89   7.732  7.767  8.243  8.793
#   9.844  7.942  8.174  8.079  8.791 11.39   9.461 12.48  11.26   8.542
#   9.086  7.114 12.04  10.39   8.394  7.759  8.107  7.642  6.596  7.252
#   8.408 11.72  10.57   6.811  6.81   7.702 10.    10.45  11.43   8.188
#  10.5    6.798  7.19   9.82   7.381  6.718  6.72   7.422  7.657  7.465
#   8.244  6.774  6.962]
# [ 9.635  9.619  7.666  7.087  6.316  8.825 12.62   8.486  7.052  9.34
#   7.549  7.952  9.45   9.565  8.27   9.185  7.992  8.409  8.767  6.914
#  10.26   9.646  7.855  6.763  6.181  9.91   4.927  7.909  6.683  8.064
#   9.542  8.275  7.057  6.697  9.57  11.33   8.175  8.179 10.47   8.642
#   7.929  5.852  5.248  5.403  6.313  9.455  7.06   7.268  5.879  5.65
#   9.575  8.518  6.5    6.603  8.051  8.071  8.995  9.618  8.001 11.57
#   6.957  9.362  8.911  7.266  8.825 12.42   7.769  6.161  8.654  7.997
#   8.673  8.79   5.802  7.935  9.86   6.104  8.747  7.593  5.009  6.888
#   9.543 10.33   7.163  7.494  7.797 11.08  10.39   9.096  7.121 10.25
#   9.16   8.941  9.369  9.092  6.381 10.68   9.506  9.86  11.21   8.863
#   5.577 11.3    6.936 12.38   7.02  10.12   7.528  7.359  6.253  6.59
#   6.292  4.69  10.41   5.874  8.278  6.652 11.6    9.302  4.465  8.598
#  11.42   6.935  7.431 10.42   9.218  8.367  7.303 10.57   6.748 10.67
#   5.914 11.41   6.593  6.213  7.958  5.532  6.979  8.488 10.46  10.83
#   8.368 10.34   9.45   8.929  8.418  7.591  7.353  9.636 10.82   7.184
#   8.72  10.8   11.48   5.823  9.294  7.278  9.217 10.59  11.06  10.65
#   9.072  9.79   8.623  7.786  8.428  7.026 10.06   8.111  8.922  6.856
#  10.85  11.33   9.544  5.917  7.612  9.785  7.936  6.54   7.519  8.02
#   8.985  6.681  8.137  7.96   9.56  10.98   9.416 12.94  11.92   9.138
#   9.068  7.29  13.23  11.11   9.685  8.812  9.35   7.322  7.818  6.52
#   8.508 11.51  11.03   6.601  6.965  6.813 10.21  10.51   9.361  8.13
#   9.919  6.133  6.507 10.68   6.495  6.808  6.653  4.892  7.359  7.019
#   8.98   7.934  6.849]
# [12.55   9.556  8.71   6.852  7.046  8.756 12.04   8.286  7.164  8.326
#   9.23   7.213  9.506 10.04   8.    11.19   8.068  7.969  8.734  6.996
#  10.01   9.794  8.728  7.051  7.22  10.52   5.98   5.453  7.319  7.932
#   9.62   7.99   7.948  7.415  9.246 12.57   8.88   7.436 10.96   9.286
#   7.163  6.322  5.39   5.318  6.022 10.02   6.854  8.978  6.618  5.858
#  10.06   9.117  6.741  8.873  7.2    5.822  9.093  8.371  7.738 10.79
#   7.398  9.937  8.916  6.872 11.14   9.783  8.078  6.453  9.005  9.364
#   9.456  9.286  5.134  6.468  9.553  7.28  11.54   8.273  5.038  7.119
#   9.579 11.04   7.972  6.713  8.251 12.29   9.457  9.593  7.562  9.906
#   9.044  8.711  9.175  9.018  8.222 10.69   8.989 10.45  10.47   9.972
#   5.619 10.84   6.368 12.25   7.709  9.943  7.544  6.276  5.79   6.43
#   6.016  9.69  10.19   7.926  8.523  6.577 11.03   8.32   4.471  9.164
#  11.49   7.829  8.159 10.63   8.439  6.019  7.6    9.406  6.31   9.839
#   5.617 10.61   7.792  6.112  8.372  6.479  7.163  8.136  9.284 10.95
#   7.858 10.54   9.701  8.232  9.696  7.605  7.272  9.402 10.41   7.314
#   8.661 11.37  12.48   5.527  8.521  7.622  8.501  8.86  11.28  10.4
#   8.844 10.11   9.504  8.036  8.756  7.85  10.17   7.919  8.331  6.432
#  11.15  11.48   9.376  5.938  8.314  9.386  7.897  8.808  8.462  7.649
#   9.624  8.916  7.632  8.825  8.674 10.64   9.305 11.43   9.822  9.49
#   8.85   6.816 10.33   9.187  9.037  7.856  9.743  7.63   7.328  7.825
#   9.221 11.98   9.594  6.954  6.89   7.134 11.24  11.31  10.84   7.891
#   9.398  5.728  6.936  9.311  6.732  6.64   6.498  9.854  8.027  7.033
#   8.724  6.694  7.503]
# [10.68   9.448  7.234  7.951  7.117  8.453 12.97   9.355  6.827  9.746
#   9.842  7.409 10.37  10.11   8.051  9.961  8.059  8.138  8.986  6.413
#  11.23   6.607  8.201  8.889  7.4   10.09   7.081  6.877  6.668  8.555
#   9.356  8.246  7.362  7.288 10.04  11.54   8.835  7.812 11.96   9.572
#   7.093  5.82   5.643  6.073  5.928  9.638  7.226  9.484  5.754  5.162
#   9.833  8.888  6.009  6.471  6.623  6.075  9.256  8.262  8.353 11.78
#   8.794 10.01   9.164  7.384 11.38  10.47   6.994  7.472  9.338  9.758
#   8.955  9.948  7.595  9.911  8.834  7.748 12.56   8.462  5.187  7.401
#  10.21  11.38   8.098  7.236  7.929 11.12   9.569  9.661  8.562 10.68
#   9.456  8.75   9.705  8.912  8.448 11.9    9.413 10.39  11.33   9.135
#   5.522 10.82   5.937 12.51   8.626  9.624  7.582  7.88   5.767  6.249
#   6.301  7.815 11.73   6.209  8.163  6.534  9.989  9.378  3.96   8.569
#  10.38   7.473  7.358 10.61   8.608  7.637  7.116  9.375  6.662  9.354
#   6.245  8.048  6.609  5.566  7.433  5.261  6.805  9.127  9.617  9.845
#   7.952  9.669  9.599  9.073  9.091  7.373  7.684  9.219 10.04   6.979
#   7.965 10.21  11.83   6.159  6.799  7.562  8.747  9.111 11.44  10.23
#   8.488  9.626  8.613  7.241  8.292  7.307 10.26   8.206  8.592  6.596
#  10.58  11.09   9.64   5.518  7.989  9.462  7.52   8.229  7.983  8.297
#   8.306  8.37   7.316  8.009  9.045 10.45   9.464 12.16  10.1    8.932
#   9.362  6.707 10.6    9.577  8.457  7.501 10.84   7.833  7.226  5.933
#   8.679 10.95  10.42   7.408  7.113  8.195 11.35  10.    11.63   8.07
#   9.428  5.945  6.915 10.7    7.857  6.284  6.303  9.176  7.744  7.395
#   8.234  7.888  7.446]
# [10.15  10.02   8.31   8.369  7.018  8.5   12.04   7.987  7.595  8.118
#  11.25   8.125  9.088 10.15   8.006  9.16   7.849  9.225  9.587  6.572
#   8.91   8.431  8.337  7.035  6.565 10.27   7.494  8.254  6.844  7.036
#  10.01   8.345  7.59   7.598  9.406 11.46   8.767  8.544 11.47   9.444
#   7.682  9.932  5.355  5.896  7.525  9.291  7.572  9.142  6.492  5.796
#  10.2    9.708  6.736  9.261  8.123  6.558 10.59   7.941  7.96  11.22
#   6.447  8.156  7.975  7.228 11.64   9.983  7.359  6.889 10.16   9.87
#   9.792  9.692  5.323  8.359  9.965  7.006 12.13   8.725  6.197  7.339
#   8.498 11.97   7.804  6.994  7.089 10.89  10.88   9.558 10.71  11.16
#   8.656  9.369 10.15   8.29   8.883 10.34   8.748  9.318 10.15   8.715
#   5.869 11.92   6.128 13.06   9.124  9.185  6.972  7.822  6.031  6.408
#   6.36  10.27  10.7    6.486  9.162  6.186 11.38   8.765  5.416  8.894
#  11.88   8.047  7.427 10.99   9.388  8.321  8.026  9.79   6.238 10.58
#   5.929 10.13   7.794  5.742  7.45   6.654  7.424  7.896  8.841 10.02
#   8.844 10.98   8.593  8.124  9.49   7.804  7.435 11.04  11.74   7.675
#   8.962  8.392 11.59   6.839  7.313  8.93   8.     9.094 11.68  10.31
#   8.689  9.844  9.985  8.987 10.53   7.756  9.349  7.866  8.197  7.224
#  10.24  11.43   8.829  6.132  7.661  9.653  7.261  7.854  9.74   9.163
#   9.28  10.61   8.899  8.852  9.174 11.72   9.958 12.9    9.694 10.65
#   8.523  8.04  12.18  11.74   9.837  9.122 10.68   6.788  8.15   8.377
#   8.282 11.84   8.763  6.922  6.426  7.918 10.37   8.964 11.76   7.669
#   8.748  5.081  6.831  9.903  7.869  6.328  6.406  5.689  8.138  7.032
#   7.448  9.127  7.018]
# [ 9.59  10.19   8.62   9.341  6.966  9.125 11.41   9.676  5.765  9.098
#  12.88   5.967  9.532 10.43   7.596  8.35   7.922  7.59   9.421  5.493
#   8.916  8.478  8.552  7.685  6.994 10.56   6.374  6.733  6.983  8.431
#  10.63   9.166  8.647  7.272  9.996 12.19   8.169  7.871 10.55   9.839
#   7.37   6.838  5.857  5.808  6.961  9.171  7.178  9.504  7.016  6.644
#  10.53   9.194  7.108  8.532  7.632  6.226  7.212  7.248  7.86  11.76
#   6.898  8.828  8.121  7.542    nan 10.61   7.103  6.548  8.356  8.306
#   7.27   9.258  4.916  6.935  8.984  7.196 10.46   7.151  5.352  6.673
#   8.026  9.022  9.344  7.006  8.68  11.39   9.276  8.195  9.86   9.459
#   9.239  9.139 10.47   9.356  9.89   9.945 10.05   9.112 11.01  10.33
#   5.944  9.184  6.275  8.263  6.49   9.877  5.908  7.334  5.358  6.892
#   6.912  9.016  9.801  6.517  8.219  6.653 10.8    8.695  5.253  9.22
#  11.04   7.822  7.206  9.996  8.379  7.62   8.071  9.937  6.358  9.817
#   5.988 11.66   7.815  6.171  6.682  6.249  6.876  8.654  8.528  9.221
#   8.345 10.18  11.59   8.864  9.385  7.314  7.497 10.39  10.25   7.056
#   8.837  8.911 11.54   6.144  9.05   7.678  9.176 10.16  10.43  11.38
#   9.397 10.38   9.879  8.025  9.497  7.476  9.548  8.665  9.208  7.28
#  12.53  11.64   9.386  6.114  9.055 10.22   7.274  9.919  7.966  7.397
#   9.581  9.243  7.756  8.746  8.784 11.19   8.746 11.2    8.665 10.36
#   8.98   6.729  9.813  8.863  8.33   7.061  9.994  7.909  7.483  7.615
#   8.586 13.03  11.49   7.211  6.581  7.636 11.56   9.238 11.84   8.818
#   9.615  6.201  7.326  9.659  7.478  6.713  6.865  9.962  8.864  8.701
#   7.924  6.672  7.645]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vh/rzymgl1d6c79q_4lhgmys8cm0000gn/T/ipykernel_57457/1835554253.py in ?()
#      38     print(x)
#      39     x_filt = x[~np.isnan(x)]
#      40     # if np.isnan(x).any():
#      41     #     sig_sub['HRD'].loc[]
# ---> 42     r_hrd = pearsonr(x_filt, sig_sub['HRD'].values)[0]
#      43     r_hrp = pearsonr(x_filt, sig_sub['HR_proficient'].values)[0]
#      44     hrd_scores[samp] = r_hrd - r_hrp
#      45
#
# ~/miniconda3/envs/HRDclass/lib/python3.12/site-packages/scipy/stats/_stats_py.py in ?(x, y, alternative, method)
#    4717
#    4718     """
#    4719     n = len(x)
#    4720     if n != len(y):
# -> 4721         raise ValueError('x and y must have the same length.')
#    4722
#    4723     if n < 2:
#    4724         raise ValueError('x and y must have length at least 2.')
#
# ValueError: x and y must have the same length.

# %%
# 12. Boxplot of HRD_score by pCR.status + scatter + stats
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import ttest_ind, mannwhitneyu

# use your cleaned DataFrame
df = hrd_clean  # rename if yours is different

# define groups
labels = ['Non‑responder', 'Responder']
groups = [0, 1]
data_to_plot = [df.loc[df['pCR.status'] == g, 'HRD_score'] for g in groups]

# boxplot
plt.figure(figsize=(8,6))
boxprops   = dict(linestyle='-', linewidth=2, color='black')
medianprops= dict(linestyle='-', linewidth=2.5, color='firebrick')
plt.boxplot(data_to_plot,
            labels=labels,
            patch_artist=True,
            boxprops=boxprops,
            medianprops=medianprops)

# jittered scatter
for i, g in enumerate(groups):
    y = df.loc[df['pCR.status'] == g, 'HRD_score']
    x = np.random.normal(i+1, 0.04, size=len(y))
    plt.scatter(x, y, alpha=0.6)

plt.title('Distribution of HRD_score by pCR.status')
plt.xlabel('pCR.status')
plt.ylabel('HRD_score')
plt.show()

# 13. Statistical tests
g0 = df.loc[df['pCR.status'] == 0, 'HRD_score']
g1 = df.loc[df['pCR.status'] == 1, 'HRD_score']

t_stat, p_t = ttest_ind(g0, g1, equal_var=False)
u_stat, p_u = mannwhitneyu(g0, g1, alternative='two-sided')

print(f"Welch's t‑test: t = {t_stat:.4f}, p = {p_t:.4f}")
print(f"Mann–Whitney U test: U = {u_stat:.4f}, p = {p_u:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       4 from scipy.stats import ttest_ind, mannwhitneyu
#       6 # use your cleaned DataFrame
# ----> 7 df = hrd_clean  # rename if yours is different
#       9 # define groups
#      10 labels = ['Non‑responder', 'Responder']
#
# NameError: name 'hrd_clean' is not defined

# %%
f1
mathews
confusion matrix
ccle
per-subtype

# %%
# -------------------- Data Loading and Preprocessing --------------------

# Load metadata and HRD scores
data_dir = "./data/"
ann_tcga = pd.read_csv(f"{data_dir}toga.breast.brca.status.txt", sep='\t', index_col=0)
hrd_scores = pd.read_excel(f"{data_dir}tcga.hrdscore.xlsx", index_col=0)

# Load RNAseq data
fpkm = pd.read_csv(f"{data_dir}tcga.brca.rnaseq.unstranded.fpkm.counts.matrix.txt", sep='\t', index_col=0)

# Filter metadata
metadata = ann_tcga[~ann_tcga['event.RAD51C'].ne('0')]
metadata = metadata[~metadata['event.PALB2'].ne('0')]
metadata = metadata[metadata['event.BRCA1'] != '1']
metadata.index = metadata.index.str.replace('.', '-', regex=False)
hrd_scores.index = hrd_scores.index.map(lambda x: x[:12])
metadata = metadata.merge(hrd_scores[['HRD-sum']], left_index=True, right_index=True, how='inner')

# Process fpkm data
fpkm = fpkm.set_index('Case ID')
fpkm = fpkm[fpkm['Sample Type'] == 'Primary Tumor']
fpkm = fpkm.drop(columns=["Sample ID","Sample Type"])

filtered_columns = [col for col in fpkm.columns if '|' in col and 'protein_coding' in col.split('|')[2]]
fpkm = fpkm[filtered_columns]

# Further processing for fpkm
fpkm.columns = [col.split('|')[1] if '|' in col else col for col in fpkm.columns]
fpkm.index = fpkm.index.map(lambda x: x[:12])
fpkm = fpkm.loc[fpkm.index.intersection(metadata.index)]
fpkm.sort_index(inplace=True)
fpkm = fpkm.rename_axis("fpkm", axis="index")
fpkm = fpkm.apply(pd.to_numeric, errors='coerce')
fpkm.fillna(0, inplace=True)



features_df = fpkm
metadata_truncated = metadata.loc[metadata.index.intersection(features_df.index)]
# Add a base HRD status (not used in the final regression but for DESeq2 design)
metadata_truncated['HRD_status_base'] = metadata_truncated['HRD-sum'].apply(lambda x: 'HRD' if x >= 42 else 'HR')
metadata_truncated = metadata_truncated.sort_index()

features_df = features_df.fillna(0).astype(int)
features_df = features_df[sorted(features_df.columns)]

# %%
features_df = np.log2(features_df + 1)

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix
import matplotlib.pyplot as plt

# 1. Load centroids (adjust path as needed)
centroids = pd.read_csv('data/validation/pre_data/Table S4-Table 1.csv', index_col=0, skiprows=1)
# Identify the two template columns
hrd_col  = next(c for c in centroids.columns if 'hrd' in c.lower())
hrp_col  = next(c for c in centroids.columns if 'proficient' in c.lower())
sig = centroids[[hrd_col, hrp_col]]
sig.columns = ['HRD', 'HR_proficient']

# 2. Subset to common genes
genes = sig.index.intersection(features_df.columns)
sig_sub = sig.loc[genes]
expr_sub = features_df[genes]

# 3. Compute prediction scores per sample
pred_scores = {}
for sample in expr_sub.index:
    x = expr_sub.loc[sample].values
    r_hrd = pearsonr(x, sig_sub['HRD'].values)[0]
    r_hrp = pearsonr(x, sig_sub['HR_proficient'].values)[0]
    pred_scores[sample] = r_hrd - r_hrp

pred_df = pd.DataFrame.from_dict(pred_scores, orient='index', columns=['pred_score'])
pred_df.index.name = 'CaseID'

# 4. Merge with ground truth
pred_df = pred_df.merge(
    metadata_truncated[['HRD-sum','HRD_status_base']],
    left_index=True, right_index=True
)

# 5. Scatter: predicted score vs HRD-sum
plt.figure()
plt.scatter(pred_df['HRD-sum'], pred_df['pred_score'], alpha=0.7)
plt.xlabel('True HRD-sum')
plt.ylabel('Predicted HRD score')
plt.title('Predicted vs True HRD-sum')
plt.show()

# 6. ROC curve at threshold 42 for binary label
y_true  = (pred_df['HRD-sum'] >= 42).astype(int)
y_score = pred_df['pred_score']
auc      = roc_auc_score(y_true, y_score)
fpr, tpr, _ = roc_curve(y_true, y_score)

y_pred = (y_score >= 0).astype(int)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)

# Add predictions to dataframe for inspection
pred_df['y_true'] = y_true
pred_df['y_pred'] = y_pred

# Extract samples by class
tp_samples = pred_df[(pred_df['y_true'] == 1) & (pred_df['y_pred'] == 1)].index.tolist()
tn_samples = pred_df[(pred_df['y_true'] == 0) & (pred_df['y_pred'] == 0)].index.tolist()
fp_samples = pred_df[(pred_df['y_true'] == 0) & (pred_df['y_pred'] == 1)].index.tolist()
fn_samples = pred_df[(pred_df['y_true'] == 1) & (pred_df['y_pred'] == 0)].index.tolist()

print(f"True Positives: {tp_samples}")
print(f"True Negatives: {tn_samples}")
print(f"False Positives: {fp_samples}")
print(f"False Negatives: {fn_samples}")

plt.figure()
plt.plot(fpr, tpr)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC curve (AUC = {auc:.2f})')
plt.show()
# Out:
# Confusion Matrix:
#  [[541 142]
#  [ 46 158]]
# True Positives: ['TCGA-A1-A0SO', 'TCGA-A2-A04T', 'TCGA-A2-A0CM', 'TCGA-A2-A0D0', 'TCGA-A2-A0D2', 'TCGA-A2-A0EQ', 'TCGA-A2-A0T0', 'TCGA-A2-A0T1', 'TCGA-A2-A0YJ', 'TCGA-A2-A0YM', 'TCGA-A2-A0YT', 'TCGA-A2-A25B', 'TCGA-A2-A25E', 'TCGA-A2-A4S3', 'TCGA-A7-A0CJ', 'TCGA-A7-A2KD', 'TCGA-A7-A4SA', 'TCGA-A7-A4SD', 'TCGA-A7-A4SE', 'TCGA-A7-A5ZV', 'TCGA-A7-A6VW', 'TCGA-A7-A6VY', 'TCGA-A8-A06R', 'TCGA-A8-A06X', 'TCGA-A8-A079', 'TCGA-A8-A07C', 'TCGA-A8-A07U', 'TCGA-A8-A07W', 'TCGA-A8-A08F', 'TCGA-A8-A08I', 'TCGA-A8-A08L', 'TCGA-A8-A097', 'TCGA-A8-A09A', 'TCGA-A8-A09M', 'TCGA-A8-A09W', 'TCGA-AC-A2BK', 'TCGA-AN-A04A', 'TCGA-AN-A04D', 'TCGA-AN-A0AJ', 'TCGA-AN-A0AM', 'TCGA-AN-A0AR', 'TCGA-AN-A0AT', 'TCGA-AN-A0FX', 'TCGA-AN-A0FY', 'TCGA-AN-A0XU', 'TCGA-AO-A03O', 'TCGA-AO-A03T', 'TCGA-AO-A0J2', 'TCGA-AO-A0J3', 'TCGA-AO-A0J4', 'TCGA-AO-A0JD', 'TCGA-AO-A124', 'TCGA-AO-A129', 'TCGA-AO-A12F', 'TCGA-AO-A1KR', 'TCGA-AQ-A04J', 'TCGA-AR-A0TP', 'TCGA-AR-A0TS', 'TCGA-AR-A0TU', 'TCGA-AR-A0U2', 'TCGA-AR-A1AH', 'TCGA-AR-A1AI', 'TCGA-AR-A24H', 'TCGA-AR-A24L', 'TCGA-AR-A24Q', 'TCGA-AR-A2LR', 'TCGA-B6-A0I6', 'TCGA-B6-A0IJ', 'TCGA-B6-A0IQ', 'TCGA-B6-A0RE', 'TCGA-B6-A0RS', 'TCGA-B6-A3ZX', 'TCGA-BH-A0AV', 'TCGA-BH-A0B3', 'TCGA-BH-A0B4', 'TCGA-BH-A0BG', 'TCGA-BH-A0BL', 'TCGA-BH-A0BW', 'TCGA-BH-A0BZ', 'TCGA-BH-A0C0', 'TCGA-BH-A0HX', 'TCGA-BH-A0HY', 'TCGA-BH-A0WA', 'TCGA-BH-A18Q', 'TCGA-BH-A18T', 'TCGA-BH-A18U', 'TCGA-BH-A18V', 'TCGA-BH-A1F0', 'TCGA-BH-A1FN', 'TCGA-BH-A203', 'TCGA-BH-A5IZ', 'TCGA-C8-A12K', 'TCGA-C8-A12L', 'TCGA-C8-A12P', 'TCGA-C8-A12U', 'TCGA-C8-A130', 'TCGA-C8-A1HG', 'TCGA-C8-A1HM', 'TCGA-C8-A26Y', 'TCGA-C8-A27A', 'TCGA-D8-A13Y', 'TCGA-D8-A147', 'TCGA-D8-A1JD', 'TCGA-D8-A1JL', 'TCGA-D8-A1JM', 'TCGA-D8-A1JP', 'TCGA-D8-A1X9', 'TCGA-D8-A1XK', 'TCGA-D8-A1XL', 'TCGA-D8-A1XQ', 'TCGA-D8-A27F', 'TCGA-D8-A27H', 'TCGA-D8-A27M', 'TCGA-D8-A27R', 'TCGA-E2-A14N', 'TCGA-E2-A14P', 'TCGA-E2-A14R', 'TCGA-E2-A14W', 'TCGA-E2-A150', 'TCGA-E2-A158', 'TCGA-E2-A15A', 'TCGA-E2-A15S', 'TCGA-E2-A1L7', 'TCGA-E2-A1LA', 'TCGA-E2-A1LI', 'TCGA-E2-A1LL', 'TCGA-E2-A574', 'TCGA-E9-A1N9', 'TCGA-E9-A1NA', 'TCGA-E9-A1NC', 'TCGA-E9-A1ND', 'TCGA-E9-A1NE', 'TCGA-E9-A1R2', 'TCGA-E9-A1R4', 'TCGA-E9-A1RF', 'TCGA-E9-A1RH', 'TCGA-E9-A22G', 'TCGA-E9-A244', 'TCGA-E9-A2JS', 'TCGA-E9-A3QA', 'TCGA-E9-A5FL', 'TCGA-EW-A1OZ', 'TCGA-EW-A1P4', 'TCGA-EW-A1PB', 'TCGA-EW-A1PC', 'TCGA-EW-A1PD', 'TCGA-EW-A1PH', 'TCGA-EW-A3U0', 'TCGA-GI-A2C9', 'TCGA-GM-A3XL', 'TCGA-HN-A2NL', 'TCGA-LL-A5YP', 'TCGA-LL-A6FR', 'TCGA-OL-A5RW', 'TCGA-OL-A5S0', 'TCGA-OL-A66I', 'TCGA-OL-A6VO', 'TCGA-PE-A5DC']
# True Negatives: ['TCGA-A1-A0SB', 'TCGA-A1-A0SD', 'TCGA-A1-A0SE', 'TCGA-A1-A0SF', 'TCGA-A1-A0SG', 'TCGA-A1-A0SH', 'TCGA-A1-A0SI', 'TCGA-A1-A0SJ', 'TCGA-A1-A0SM', 'TCGA-A1-A0SN', 'TCGA-A2-A04N', 'TCGA-A2-A04V', 'TCGA-A2-A04W', 'TCGA-A2-A04X', 'TCGA-A2-A0CK', 'TCGA-A2-A0CO', 'TCGA-A2-A0CP', 'TCGA-A2-A0CQ', 'TCGA-A2-A0CR', 'TCGA-A2-A0CS', 'TCGA-A2-A0CT', 'TCGA-A2-A0CV', 'TCGA-A2-A0D1', 'TCGA-A2-A0D3', 'TCGA-A2-A0EM', 'TCGA-A2-A0EO', 'TCGA-A2-A0EP', 'TCGA-A2-A0ER', 'TCGA-A2-A0ET', 'TCGA-A2-A0EU', 'TCGA-A2-A0EW', 'TCGA-A2-A0EX', 'TCGA-A2-A0SU', 'TCGA-A2-A0SW', 'TCGA-A2-A0SY', 'TCGA-A2-A0T4', 'TCGA-A2-A0T5', 'TCGA-A2-A0T6', 'TCGA-A2-A0YC', 'TCGA-A2-A0YD', 'TCGA-A2-A0YF', 'TCGA-A2-A0YG', 'TCGA-A2-A0YI', 'TCGA-A2-A0YK', 'TCGA-A2-A0YL', 'TCGA-A2-A1FV', 'TCGA-A2-A1FW', 'TCGA-A2-A1FZ', 'TCGA-A2-A1G0', 'TCGA-A2-A1G4', 'TCGA-A2-A259', 'TCGA-A2-A25C', 'TCGA-A2-A25D', 'TCGA-A2-A3KC', 'TCGA-A2-A3KD', 'TCGA-A2-A3XU', 'TCGA-A2-A3XV', 'TCGA-A2-A3XZ', 'TCGA-A2-A4S1', 'TCGA-A2-A4S2', 'TCGA-A7-A0CD', 'TCGA-A7-A0CG', 'TCGA-A7-A0CH', 'TCGA-A7-A0D9', 'TCGA-A7-A13F', 'TCGA-A7-A13H', 'TCGA-A7-A3IY', 'TCGA-A7-A3IZ', 'TCGA-A7-A3J0', 'TCGA-A7-A3J1', 'TCGA-A7-A3RF', 'TCGA-A7-A425', 'TCGA-A7-A426', 'TCGA-A7-A4SB', 'TCGA-A7-A4SC', 'TCGA-A7-A4SF', 'TCGA-A7-A56D', 'TCGA-A7-A5ZW', 'TCGA-A7-A5ZX', 'TCGA-A8-A06P', 'TCGA-A8-A06Q', 'TCGA-A8-A06T', 'TCGA-A8-A06Y', 'TCGA-A8-A06Z', 'TCGA-A8-A076', 'TCGA-A8-A07B', 'TCGA-A8-A07E', 'TCGA-A8-A07F', 'TCGA-A8-A07J', 'TCGA-A8-A07P', 'TCGA-A8-A07Z', 'TCGA-A8-A081', 'TCGA-A8-A082', 'TCGA-A8-A083', 'TCGA-A8-A084', 'TCGA-A8-A08A', 'TCGA-A8-A08C', 'TCGA-A8-A08G', 'TCGA-A8-A08J', 'TCGA-A8-A08O', 'TCGA-A8-A08S', 'TCGA-A8-A08T', 'TCGA-A8-A08Z', 'TCGA-A8-A090', 'TCGA-A8-A091', 'TCGA-A8-A093', 'TCGA-A8-A095', 'TCGA-A8-A096', 'TCGA-A8-A099', 'TCGA-A8-A09B', 'TCGA-A8-A09C', 'TCGA-A8-A09E', 'TCGA-A8-A09G', 'TCGA-A8-A09K', 'TCGA-A8-A09N', 'TCGA-A8-A09T', 'TCGA-A8-A09V', 'TCGA-A8-A09X', 'TCGA-A8-A0A1', 'TCGA-A8-A0A2', 'TCGA-A8-A0A4', 'TCGA-A8-A0A6', 'TCGA-A8-A0A7', 'TCGA-A8-A0A9', 'TCGA-A8-A0AB', 'TCGA-A8-A0AD', 'TCGA-AC-A23C', 'TCGA-AC-A23E', 'TCGA-AC-A23G', 'TCGA-AC-A23H', 'TCGA-AC-A2FB', 'TCGA-AC-A2FE', 'TCGA-AC-A2FG', 'TCGA-AC-A2FM', 'TCGA-AC-A2FO', 'TCGA-AC-A2QI', 'TCGA-AC-A3BB', 'TCGA-AC-A3EH', 'TCGA-AC-A3HN', 'TCGA-AC-A3QP', 'TCGA-AC-A3TM', 'TCGA-AC-A3TN', 'TCGA-AC-A3W7', 'TCGA-AC-A3YJ', 'TCGA-AC-A5XS', 'TCGA-AC-A5XU', 'TCGA-AC-A62Y', 'TCGA-AC-A6IV', 'TCGA-AC-A6NO', 'TCGA-AN-A03X', 'TCGA-AN-A03Y', 'TCGA-AN-A04C', 'TCGA-AN-A0FD', 'TCGA-AN-A0FF', 'TCGA-AN-A0FK', 'TCGA-AN-A0FS', 'TCGA-AN-A0FW', 'TCGA-AN-A0XL', 'TCGA-AN-A0XO', 'TCGA-AN-A0XP', 'TCGA-AN-A0XR', 'TCGA-AN-A0XS', 'TCGA-AN-A0XT', 'TCGA-AN-A0XV', 'TCGA-AO-A03L', 'TCGA-AO-A03M', 'TCGA-AO-A03N', 'TCGA-AO-A03R', 'TCGA-AO-A03U', 'TCGA-AO-A0J5', 'TCGA-AO-A0J8', 'TCGA-AO-A0J9', 'TCGA-AO-A0JA', 'TCGA-AO-A0JE', 'TCGA-AO-A0JF', 'TCGA-AO-A0JG', 'TCGA-AO-A0JI', 'TCGA-AO-A0JJ', 'TCGA-AO-A0JM', 'TCGA-AO-A125', 'TCGA-AO-A126', 'TCGA-AO-A12A', 'TCGA-AO-A12B', 'TCGA-AO-A12G', 'TCGA-AO-A1KO', 'TCGA-AO-A1KP', 'TCGA-AO-A1KT', 'TCGA-AQ-A0Y5', 'TCGA-AQ-A1H2', 'TCGA-AQ-A1H3', 'TCGA-AQ-A54N', 'TCGA-AQ-A54O', 'TCGA-AR-A0TR', 'TCGA-AR-A0TX', 'TCGA-AR-A0TZ', 'TCGA-AR-A1AK', 'TCGA-AR-A1AL', 'TCGA-AR-A1AN', 'TCGA-AR-A1AP', 'TCGA-AR-A1AS', 'TCGA-AR-A1AU', 'TCGA-AR-A1AV', 'TCGA-AR-A24K', 'TCGA-AR-A24M', 'TCGA-AR-A24N', 'TCGA-AR-A24O', 'TCGA-AR-A24P', 'TCGA-AR-A24R', 'TCGA-AR-A24W', 'TCGA-AR-A24X', 'TCGA-AR-A24Z', 'TCGA-AR-A2LE', 'TCGA-AR-A2LJ', 'TCGA-AR-A2LL', 'TCGA-AR-A2LM', 'TCGA-AR-A2LN', 'TCGA-AR-A2LO', 'TCGA-AR-A5QM', 'TCGA-AR-A5QN', 'TCGA-AR-A5QP', 'TCGA-B6-A0I5', 'TCGA-B6-A0I9', 'TCGA-B6-A0IA', 'TCGA-B6-A0IB', 'TCGA-B6-A0IC', 'TCGA-B6-A0IE', 'TCGA-B6-A0IG', 'TCGA-B6-A0IH', 'TCGA-B6-A0IM', 'TCGA-B6-A0IN', 'TCGA-B6-A0IO', 'TCGA-B6-A0IP', 'TCGA-B6-A0RH', 'TCGA-B6-A0RI', 'TCGA-B6-A0RL', 'TCGA-B6-A0RM', 'TCGA-B6-A0RN', 'TCGA-B6-A0RO', 'TCGA-B6-A0RP', 'TCGA-B6-A0RV', 'TCGA-B6-A0WS', 'TCGA-B6-A0WT', 'TCGA-B6-A0WV', 'TCGA-B6-A0WY', 'TCGA-B6-A0WZ', 'TCGA-B6-A0X0', 'TCGA-B6-A0X5', 'TCGA-B6-A0X7', 'TCGA-B6-A1KC', ...
# False Positives: ['TCGA-A1-A0SK', 'TCGA-A1-A0SP', 'TCGA-A2-A04Q', 'TCGA-A2-A04R', 'TCGA-A2-A04Y', 'TCGA-A2-A0CL', 'TCGA-A2-A0CU', 'TCGA-A2-A0CW', 'TCGA-A2-A0CX', 'TCGA-A2-A0D4', 'TCGA-A2-A0EV', 'TCGA-A2-A0SV', 'TCGA-A2-A0SX', 'TCGA-A2-A0T2', 'TCGA-A2-A0T7', 'TCGA-A2-A0YE', 'TCGA-A2-A0YH', 'TCGA-A2-A1FX', 'TCGA-A2-A1G1', 'TCGA-A2-A3XX', 'TCGA-A2-A4RX', 'TCGA-A8-A06N', 'TCGA-A8-A06O', 'TCGA-A8-A07I', 'TCGA-A8-A07O', 'TCGA-A8-A085', 'TCGA-A8-A086', 'TCGA-A8-A08B', 'TCGA-A8-A092', 'TCGA-A8-A09D', 'TCGA-A8-A09R', 'TCGA-A8-A09Z', 'TCGA-AC-A62V', 'TCGA-AC-A62X', 'TCGA-AC-A6IW', 'TCGA-AN-A041', 'TCGA-AN-A049', 'TCGA-AN-A0AS', 'TCGA-AN-A0FJ', 'TCGA-AN-A0FV', 'TCGA-AN-A0G0', 'TCGA-AO-A03P', 'TCGA-AO-A0J7', 'TCGA-AO-A128', 'TCGA-AO-A1KS', 'TCGA-AQ-A04H', 'TCGA-AR-A0TQ', 'TCGA-AR-A0TV', 'TCGA-AR-A0TY', 'TCGA-AR-A0U0', 'TCGA-AR-A1AJ', 'TCGA-AR-A1AQ', 'TCGA-AR-A1AR', 'TCGA-AR-A1AW', 'TCGA-AR-A1AX', 'TCGA-AR-A1AY', 'TCGA-AR-A24S', 'TCGA-AR-A24U', 'TCGA-AR-A24V', 'TCGA-AR-A254', 'TCGA-AR-A255', 'TCGA-AR-A2LK', 'TCGA-B6-A0I2', 'TCGA-B6-A0IK', 'TCGA-B6-A0RG', 'TCGA-B6-A0RU', 'TCGA-B6-A0WW', 'TCGA-B6-A0WX', 'TCGA-B6-A1KF', 'TCGA-B6-A402', 'TCGA-B6-A409', 'TCGA-BH-A0B1', 'TCGA-BH-A0B9', 'TCGA-BH-A0BF', 'TCGA-BH-A0C7', 'TCGA-BH-A0DD', 'TCGA-BH-A0DG', 'TCGA-BH-A0DL', 'TCGA-BH-A0E2', 'TCGA-BH-A0E6', 'TCGA-BH-A0GY', 'TCGA-BH-A0HB', 'TCGA-BH-A0RX', 'TCGA-BH-A18G', 'TCGA-BH-A18J', 'TCGA-BH-A18L', 'TCGA-BH-A18R', 'TCGA-BH-A1EO', 'TCGA-BH-A1F6', 'TCGA-BH-A1F8', 'TCGA-BH-A1FC', 'TCGA-BH-A1FE', 'TCGA-BH-A1FM', 'TCGA-BH-A1FU', 'TCGA-BH-A202', 'TCGA-BH-A204', 'TCGA-BH-A209', 'TCGA-BH-A42T', 'TCGA-C8-A12M', 'TCGA-C8-A12T', 'TCGA-C8-A137', 'TCGA-C8-A1HF', 'TCGA-C8-A1HN', 'TCGA-C8-A1HO', 'TCGA-C8-A273', 'TCGA-D8-A143', 'TCGA-D8-A1JC', 'TCGA-D8-A1JJ', 'TCGA-D8-A1JT', 'TCGA-D8-A1X5', 'TCGA-D8-A1XS', 'TCGA-D8-A1XT', 'TCGA-D8-A1XZ', 'TCGA-D8-A1Y2', 'TCGA-D8-A1Y3', 'TCGA-D8-A27W', 'TCGA-E2-A105', 'TCGA-E2-A109', 'TCGA-E2-A14X', 'TCGA-E2-A14Y', 'TCGA-E2-A155', 'TCGA-E2-A159', 'TCGA-E2-A1IG', 'TCGA-E2-A1II', 'TCGA-E2-A1LK', 'TCGA-E2-A573', 'TCGA-E9-A1N8', 'TCGA-E9-A1R7', 'TCGA-E9-A1RB', 'TCGA-E9-A228', 'TCGA-E9-A22A', 'TCGA-E9-A248', 'TCGA-E9-A54Y', 'TCGA-EW-A1OV', 'TCGA-EW-A1OX', 'TCGA-EW-A1P0', 'TCGA-EW-A1P8', 'TCGA-EW-A2FV', 'TCGA-GM-A2DL', 'TCGA-GM-A2DO', 'TCGA-LL-A73Y', 'TCGA-OL-A5D7']
# False Negatives: ['TCGA-A2-A0EY', 'TCGA-A2-A0T3', 'TCGA-A2-A3XS', 'TCGA-A7-A0CE', 'TCGA-A7-A26G', 'TCGA-A8-A06U', 'TCGA-A8-A07G', 'TCGA-A8-A08X', 'TCGA-A8-A094', 'TCGA-A8-A09I', 'TCGA-A8-A09Q', 'TCGA-AN-A0AL', 'TCGA-AN-A0FL', 'TCGA-AO-A03V', 'TCGA-AO-A12D', 'TCGA-AR-A0TW', 'TCGA-AR-A0U3', 'TCGA-B6-A0I1', 'TCGA-B6-A0I8', 'TCGA-B6-A1KN', 'TCGA-BH-A0AZ', 'TCGA-BH-A0BP', 'TCGA-BH-A0H7', 'TCGA-BH-A1F2', 'TCGA-BH-A5J0', 'TCGA-C8-A12Q', 'TCGA-D8-A13Z', 'TCGA-D8-A142', 'TCGA-D8-A1JB', 'TCGA-D8-A1JK', 'TCGA-D8-A1Y0', 'TCGA-E2-A15M', 'TCGA-E2-A1B0', 'TCGA-E2-A1LE', 'TCGA-E9-A1NF', 'TCGA-E9-A1RE', 'TCGA-E9-A1RG', 'TCGA-E9-A22E', 'TCGA-E9-A243', 'TCGA-E9-A247', 'TCGA-E9-A3HO', 'TCGA-EW-A1J5', 'TCGA-EW-A1OY', 'TCGA-EW-A6SD', 'TCGA-GI-A2C8', 'TCGA-GM-A2DB']

# %%
conf_samples = {"True Positives": tp_samples, "True Negatives": tn_samples, "False Positives": fp_samples,"False Negatives":fn_samples}

# %%
tcga_survival = pd.read_csv('/Users/johnsmith/Desktop/Senior_Design_Stuff/Multiscale_HRD_Classifier/data/TCGA_CDR/mmc1/TCGA-CDR-Table 1.csv')

# %%
tcga_cdr_class = {}
for k in conf_samples.keys():
    training_samples = set(conf_samples[k])
    cdr_samples = set(tcga_survival['bcr_patient_barcode'])
    common_survival_samples = training_samples.intersection(cdr_samples)

    tcga_cdr_class[k] = tcga_survival[tcga_survival['bcr_patient_barcode'].isin(common_survival_samples)]

# %%
import numpy as np
import pandas as pd
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test
import matplotlib.pyplot as plt

def perform_survival_analysis(tcga_cdr_class, survival_time_col, survival_status_col):
    """
    Perform survival analysis with NaN handling and log-rank test.
    Adds p-values and χ² statistics as an on-plot annotation.
    """
    colors = {                      # unchanged
        'True Positives': '#1B9E77',
        'True Negatives': '#D95F02',
        'False Positives': '#7570B3',
        'False Negatives': '#E7298A',
        'HR': '#FF0000',
        'HRD':'#0000FF'
    }

    plt.figure(figsize=(12, 8))
    survival_results, log_rank_results = {}, {}

    cleaned_data = {}
    for category, df in tcga_cdr_class.items():
        cleaned = df.dropna(subset=[survival_time_col, survival_status_col])
        cleaned = cleaned[cleaned[survival_time_col] <= 1825]
        if cleaned.empty:
            print(f"Warning: No valid data for category {category}")
            continue
        cleaned_data[category] = cleaned

    if len(cleaned_data) < 2:
        raise ValueError("Not enough categories with valid data for survival analysis")

    categories = list(cleaned_data.keys())
    for cat in categories:
        kmf = KaplanMeierFitter()
        d = cleaned_data[cat]
        kmf.fit(
            durations=d[survival_time_col],
            event_observed=d[survival_status_col],
            label=cat
        )
        kmf.plot(ci_show=False, color=colors.get(cat, 'gray'),
                 label=f"{cat} (n={len(d)})")
        survival_results[cat] = kmf

    # ---------- log-rank tests & annotation ----------------------------------
    anno_lines = []                                  # 👈  NEW
    for i in range(len(categories)):
        for j in range(i + 1, len(categories)):
            c1, c2 = categories[i], categories[j]
            res = logrank_test(
                cleaned_data[c1][survival_time_col],
                cleaned_data[c2][survival_time_col],
                cleaned_data[c1][survival_status_col],
                cleaned_data[c2][survival_status_col]
            )
            log_rank_results[f"{c1} vs {c2}"] = res
            pval = res.p_value
            chi2 = res.test_statistic
            print(f"Log-rank {c1} vs {c2}: χ² = {chi2:.2f}, p = {pval:.4f}")
            anno_lines.append(f"{c1} vs {c2}: χ²={chi2:.2f}, p={pval:.3g}")  # 👈 NEW

    # place the annotation block in the top-right corner of the axes
    plt.gca().text(0.65, 0.95, "\n".join(anno_lines),   # 👈 NEW
                   transform=plt.gca().transAxes,
                   fontsize=9, verticalalignment='top',
                   bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", lw=0.8))  # 👈 NEW
    # ------------------------------------------------------------------------

    plt.title(f"Projected 5-year survival ({survival_status_col})", fontsize=16)
    plt.xlabel(survival_time_col, fontsize=12)
    plt.ylabel(survival_status_col, fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    return survival_results, log_rank_results

# %%
Trues = {key :tcga_cdr_class[key] for key in tcga_cdr_class.keys() if key in ['True Positives', 'True Negatives']}
perform_survival_analysis(Trues, 'PFI.time', 'PFI')
# Out:
# Log-rank True Positives vs True Negatives: χ² = 0.00, p = 0.9676
# ({'True Positives': <lifelines.KaplanMeierFitter:"True Positives", fitted with 129 total observations, 113 right-censored observations>,
#   'True Negatives': <lifelines.KaplanMeierFitter:"True Negatives", fitted with 427 total observations, 375 right-censored observations>},
#  {'True Positives vs True Negatives': <lifelines.StatisticalResult: logrank_test>
#                  t_0 = -1
#    null_distribution = chi squared
#   degrees_of_freedom = 1
#            test_name = logrank_test
#
#   ---
#    test_statistic    p  -log2(p)
#              0.00 0.97      0.05})

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, confusion_matrix, roc_auc_score

# 1. (Re‑)merge the PAM50 labels
pred_df = pred_df.merge(
    metadata_truncated[['event.PAM50']],
    left_index=True, right_index=True
)

# 2. Binarize ground truth & predictions
threshold = 0  # adjust if you want a different score cutoff
pred_df['true_label'] = (pred_df['HRD-sum'] >= 42).astype(int)
pred_df['pred_label'] = (pred_df['pred_score'] >= threshold).astype(int)

# 3. Overall metrics
f1  = f1_score(pred_df['true_label'], pred_df['pred_label'])
mcc = matthews_corrcoef(pred_df['true_label'], pred_df['pred_label'])
cm  = confusion_matrix(pred_df['true_label'], pred_df['pred_label'])

print("Overall performance:")
print(f"  F1 score           = {f1:.2f}")
print(f"  Matthews’ corrcoef = {mcc:.2f}")
print("  Confusion matrix:")
print(cm)

# 4. Per‑subtype F1 & AUC
print("\nPerformance by PAM50 subtype:")
for subtype, grp in pred_df.groupby('event.PAM50'):
    y_true  = grp['true_label']
    y_pred  = grp['pred_label']
    y_score = grp['pred_score']

    # skip if only one class present
    if len(np.unique(y_true)) < 2:
        print(f"  {subtype}: only one class present, skipping.")
        continue

    f1_sub  = f1_score(y_true, y_pred)
    auc_sub = roc_auc_score(y_true, y_score)
    print(f"  {subtype:<6}  F1 = {f1_sub:.2f},  AUC = {auc_sub:.2f}")
# Out:
# Overall performance:
#   F1 score           = 0.63
#   Matthews’ corrcoef = 0.50
#   Confusion matrix:
# [[541 142]
#  [ 46 158]]
#
# Performance by PAM50 subtype:
#   Basal   F1 = 0.76,  AUC = 0.72
#   Her2    F1 = 0.49,  AUC = 0.70
#   LumA    F1 = 0.42,  AUC = 0.87
#   LumB    F1 = 0.57,  AUC = 0.78

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"

import matplotlib.pyplot as plt

# Manual confusion matrix calculation to avoid heavy numpy threading
true_labels = pred_df['true_label'].tolist()
pred_labels = pred_df['pred_label'].tolist()
labels = ['Non-responder', 'Responder']

cm = [[0, 0], [0, 0]]
for t, p in zip(true_labels, pred_labels):
    cm[t][p] += 1

# Plot as heatmap
fig, ax = plt.subplots(figsize=(6, 6))
im = ax.imshow(cm)

# Annotate counts
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i][j], ha='center', va='center')

ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
ax.set_xlabel('Predicted label')
ax.set_ylabel('True label')
ax.set_title('Confusion Matrix')
plt.show()

# %%
data_dir = "./data"
genes_validation = pd.read_csv(f'{data_dir}/validation/CCLE_RNAseq_genes_counts_20180929.gct', sep="\t", skiprows=2)
# Drop the 'Ensembl IDs' column
genes_validation_transposed = genes_validation.drop(columns=['Name'])

# Set the 'Description' column as the new header (column names)
genes_validation_transposed = genes_validation_transposed.set_index('Description').transpose()

#genes_validation_transposed_sorted = genes_validation_transposed.sort_index(axis = 1)

breast_filt = genes_validation_transposed[genes_validation_transposed.index.str.contains('BREAST')]
breast_filt = breast_filt.set_index(breast_filt.index.str.split('_').str[0])
breast_filt.head()

prism = pd.read_excel(f'{data_dir}/validation/PRISM_CCLE.xlsx', skiprows=1)
prism['CellLine'] = prism['CellLine'].replace('-', '', regex=True)

samp_prism = set(list(prism['CellLine']))
samp_val_genes = set(list(breast_filt.index))

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr, ttest_ind, mannwhitneyu
import matplotlib.pyplot as plt

# --- 1. load & prep centroids ---
centroids = pd.read_csv('MultiScale_centroids.csv', index_col=0, skiprows=1)
hrd_col = next(c for c in centroids.columns if 'hrd' in c.lower())
hrp_col = next(c for c in centroids.columns if 'proficient' in c.lower())
sig = centroids[[hrd_col, hrp_col]].rename(columns={hrd_col:'HRD', hrp_col:'HR_proficient'})

# --- 2. intersect genes & compute scores ---
common = sig.index.intersection(breast_filt.columns)
expr_sub = breast_filt[common]           # samples × genes
sig_sub  = sig.loc[common]               # genes × {HRD,HR_proficient}

scores = {}
for cl in expr_sub.index:
    x = expr_sub.loc[cl].values
    r_h = pearsonr(x, sig_sub['HRD'].values)[0]
    r_p = pearsonr(x, sig_sub['HR_proficient'].values)[0]
    scores[cl] = r_h - r_p

pred_df = pd.DataFrame.from_dict(scores, orient='index', columns=['pred_score'])
pred_df.index.name = 'CellLine'

# --- 3. merge into prism & choose threshold ---
prism2 = prism.set_index('CellLine').join(pred_df, how='inner').reset_index()
thr = 0.0    # you can tweak this

# --- 4. loop through PRISM cols 3–6, stats + plots ---
for col in prism2.columns[3:7]:
    g0 = prism2.loc[prism2['pred_score'] < thr, col].dropna()
    g1 = prism2.loc[prism2['pred_score'] >= thr, col].dropna()

    t, p_t = ttest_ind(g0, g1, equal_var=False)
    u, p_u = mannwhitneyu(g0, g1, alternative='two-sided')
    print(f"\n{col}: Welch t = {t:.2f} (p={p_t:.2e}),  MW U = {u:.2f} (p={p_u:.2e})")

    fig, ax = plt.subplots(figsize=(8,6))
    bp = ax.boxplot([g0, g1],
                    positions=[0,1],
                    patch_artist=True,
                    boxprops=dict(facecolor='lightgray', linewidth=1.5),
                    medianprops=dict(color='firebrick', linewidth=2))
    # scatter
    x0 = np.random.normal(0, 0.04, size=len(g0))
    x1 = np.random.normal(1, 0.04, size=len(g1))
    ax.scatter(x0, g0, alpha=0.6, edgecolor='k')
    ax.scatter(x1, g1, alpha=0.6, edgecolor='k')

    ax.set_xticks([0,1])
    ax.set_xticklabels([f"<{thr}", f"≥{thr}"])
    ax.set_xlabel('Centroid‑score group')
    ax.set_ylabel(col)
    ax.set_title(f"{col} by prediction group")
    plt.show()
# Out:
# OLAPARIB: Welch t = nan (p=nan),  MW U = 20.00 (p=4.62e-01)
# TALAZOPARIB: Welch t = nan (p=nan),  MW U = 21.00 (p=3.85e-01)
# NIRAPARIB: Welch t = nan (p=nan),  MW U = 21.00 (p=3.85e-01)
# RUCAPARIB: Welch t = nan (p=nan),  MW U = 2.00 (p=2.40e-01)
